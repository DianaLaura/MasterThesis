# %%
library(ggplot2)
library(tidyr)
library(dplyr)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
DTA_labels_train <- read.csv("/Volumes/Korpora/Exp3b_results/DTA_Exp3b_Reg6_Labels_train.csv",sep=";", header=T)
DTA_labels_val <- read.csv("/Volumes/Korpora/Exp3b_results/DTA_Exp3b_Reg6_Labels_val.csv",sep=";", header=T)
DTA_labels_test <- read.csv("/Volumes/Korpora/Exp3b_results/DTA_Exp3b_Reg6_Labels_test.csv",sep=";", header=T)

DTA_GERMANC_labels_val <- read.csv("/Volumes/Korpora/Exp3b_results/DTA_over_GERMANC_Exp3b_Reg6_Labels_val.csv",sep=";", header=T)
DTA_GERMANC_labels_test <- read.csv("/Volumes/Korpora/Exp3b_results/DTA_over_GERMANC_Exp3b_Reg6_Labels_test.csv",sep=";", header=T)

# %%
GERMANC_labels_train <- read.csv("/Volumes/Korpora/Exp3b_results/GERMANC_Exp3b_Reg6_Labels_train.csv",sep=";", header=T)
GERMANC_labels_val <- read.csv("/Volumes/Korpora/Exp3b_results/GERMANC_Exp3b_Reg6_Labels_val.csv",sep=";", header=T)
GERMANC_labels_test <- read.csv("/Volumes/Korpora/Exp3b_results/GERMANC_Exp3b_Reg6_Labels_test.csv",sep=";", header=T)

GERMANC_DTA_labels_val <- read.csv("/Volumes/Korpora/Exp3b_results/GERMANC_DTA_Exp3b_Reg6_Labels_val.csv",sep=";", header=T)

GERMANC_DTA_labels_test <- read.csv("/Volumes/Korpora/Exp3b_results/GERMANC_DTA_Exp3b_Reg6_Labels_test.csv",sep=";", header=T)

# %%
ARCHER_labels_train <- read.csv("/Volumes/Korpora/Exp3b_results/ARCHER_Exp3b_Reg6_Labels_train.csv",sep=";", header=T)
ARCHER_labels_val <- read.csv("/Volumes/Korpora/Exp3b_results/ARCHER_Exp3b_Reg6_Labels_val.csv",sep=";", header=T)
ARCHER_labels_test <- read.csv("/Volumes/Korpora/Exp3b_results/ARCHER_Exp3b_Reg6_Labels_test.csv",sep=";", header=T)

ARCHER_CLMET_labels_val <- read.csv("/Volumes/Korpora/Exp3b_results/ARCHER_over_CLMET_Exp3b_Reg6_Labels_val.csv",sep=";", header=T)

ARCHER_CLMET_labels_test <- read.csv("/Volumes/Korpora/Exp3b_results/ARCHER_over_CLMET_Exp3b_Reg6_Labels_test.csv",sep=";", header=T)

# %%
CLMET_labels_train <- read.csv("/Volumes/Korpora/Exp3_results/CLMET_Exp3b_Reg6_Labels_train.csv",sep=";", header=T)
CLMET_labels_val <- read.csv("/Volumes/Korpora/Exp3_results/CLMET_Exp3b_Reg6_Labels_val.csv",sep=";", header=T)
CLMET_labels_test <- read.csv("/Volumes/Korpora/Exp3_results/CLMET_Exp3b_Reg6_Labels_test.csv",sep=";", header=T)

CLMET_ARCHER_labels_val <- read.csv("/Volumes/Korpora/Exp3_results/CLMET_over_ARCHER_Exp3b_Reg6_Labels_val.csv",sep=";", header=T)

CLMET_ARCHER_labels_test <- read.csv("/Volumes/Korpora/Exp3_results/CLMET_over_ARCHER_Exp3b_Reg6_Labels_test.csv",sep=";", header=T)

# %%
summary(CLMET_ARCHER_labels_test)
# Out:
#        X           Predicted_y        Year        Difference
#  Min.   :  0.00   Min.   :1839   Min.   :1609   Min.   :-158.632
#  1st Qu.: 85.25   1st Qu.:1839   1st Qu.:1764   1st Qu.: -79.857
#  Median :170.50   Median :1839   Median :1836   Median :   2.877
#  Mean   :170.50   Mean   :1839   Mean   :1833   Mean   :   6.316
#  3rd Qu.:255.75   3rd Qu.:1839   3rd Qu.:1920   3rd Qu.:  75.615
#  Max.   :341.00   Max.   :1840   Max.   :1998   Max.   : 230.365
#                   NA's   :13     NA's   :13     NA's   :26

# %%
DTA_labels_train =rename(DTA_labels_train, 'Year'=Publication_year)
DTA_labels_val =rename(DTA_labels_val, 'Year'=Publication_year)
DTA_labels_test =rename(DTA_labels_test, 'Year'=Publication_year)
GERMANC_DTA_labels_val= rename(GERMANC_DTA_labels_val, 'Year'=Publication_year)
GERMANC_DTA_labels_test= rename(GERMANC_DTA_labels_test, 'Year'=Publication_year)

# %%
DTA_labels_train['Corpus'] = 'DTA'
CLMET_labels_train['Corpus'] = 'CLMET'
ARCHER_labels_train['Corpus'] = 'ARCHER'
GERMANC_labels_train['Corpus'] = 'GerManC'

# %%
train = bind_rows(DTA_labels_train, CLMET_labels_train, ARCHER_labels_train, GERMANC_labels_train)

# %%
DTA_labels_val['Corpus'] = 'DTA'
CLMET_labels_val['Corpus'] = 'CLMET'
ARCHER_labels_val['Corpus'] = 'ARCHER'
GERMANC_labels_val['Corpus'] = 'GerManC'

# %%
val = bind_rows(DTA_labels_val, CLMET_labels_val, ARCHER_labels_val, GERMANC_labels_val)

# %%
DTA_labels_test['Corpus'] = 'DTA'
CLMET_labels_test['Corpus'] = 'CLMET'
ARCHER_labels_test['Corpus'] = 'ARCHER'
GERMANC_labels_test['Corpus'] = 'GerManC'

# %%
test = bind_rows(DTA_labels_test, CLMET_labels_test, ARCHER_labels_test, GERMANC_labels_test)

# %%
DTA_GERMANC_labels_val['Corpus'] = 'DTA over GerManC'
CLMET_ARCHER_labels_val['Corpus'] = 'CLMET over ARCHER'
ARCHER_CLMET_labels_val['Corpus'] = 'ARCHER over CLMET'
GERMANC_DTA_labels_val['Corpus'] = 'GerManC over DTA'

# %%
out_domain_val = bind_rows(DTA_GERMANC_labels_val, CLMET_ARCHER_labels_val, ARCHER_CLMET_labels_val, GERMANC_DTA_labels_val)

# %%
DTA_GERMANC_labels_test['Corpus'] = 'DTA over GerManC'
CLMET_ARCHER_labels_test['Corpus'] = 'CLMET over ARCHER'
ARCHER_CLMET_labels_test['Corpus'] = 'ARCHER over CLMET'
GERMANC_DTA_labels_test['Corpus'] = 'GerManC over DTA'

# %%
out_domain_test = bind_rows(DTA_GERMANC_labels_test, CLMET_ARCHER_labels_test, ARCHER_CLMET_labels_test, GERMANC_DTA_labels_test)

# %%
ggplot(train, aes(x=Year, y=Difference, colour = Corpus)) + geom_smooth()+ ylim(-200, 200) + labs(title="Train subword-based", x="True Year", y="Predicted Year - True Year")
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# Warning message:
# “Removed 217 rows containing non-finite values (stat_smooth).”Warning message:
# “Removed 2 rows containing missing values (geom_smooth).”
# plot without title

# %%
ggsave("labels_train_exp3b.png")
# Out:
# Saving 7 x 7 in image
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# Warning message:
# “Removed 217 rows containing non-finite values (stat_smooth).”Warning message:
# “Removed 2 rows containing missing values (geom_smooth).”

# %%
ggplot(val, aes(x=Year, y=Difference, colour = Corpus)) + geom_smooth() + ylim(-200, 200) + labs(title="Validation (In-Domain) subword-based", x="True Year", y="Predicted Year - True Year")
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# Warning message:
# “Removed 65 rows containing non-finite values (stat_smooth).”Warning message:
# “Removed 3 rows containing missing values (geom_smooth).”
# plot without title

# %%
ggsave("labels_val_exp3b.png")
# Out:
# Saving 7 x 7 in image
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# Warning message:
# “Removed 65 rows containing non-finite values (stat_smooth).”Warning message:
# “Removed 3 rows containing missing values (geom_smooth).”

# %%
ggplot(test, aes(x=Year, y=Difference, colour = Corpus)) + geom_smooth()+ ylim(-200, 200) + labs(title="Test (In-Domain) subword-based", x="True Year", y="Predicted Year - True Year")
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# Warning message:
# “Removed 66 rows containing non-finite values (stat_smooth).”Warning message:
# “Removed 4 rows containing missing values (geom_smooth).”
# plot without title

# %%
ggsave("labels_test_exp3b.png")
# Out:
# Saving 7 x 7 in image
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# Warning message:
# “Removed 66 rows containing non-finite values (stat_smooth).”Warning message:
# “Removed 4 rows containing missing values (geom_smooth).”

# %%
ggplot(out_domain_val, aes(x=Year, y=Difference, colour = Corpus)) + geom_smooth() + ylim(-200, 200) + labs(title="Out-Domain: Validation subword-based", x="True Year", y="Predicted Year - True Year")
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# Warning message:
# “Removed 61 rows containing non-finite values (stat_smooth).”
# plot without title

# %%
ggsave("label_out-domain_val_exp3b.png")
# Out:
# Saving 7 x 7 in image
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# Warning message:
# “Removed 61 rows containing non-finite values (stat_smooth).”

# %%
ggplot(out_domain_test, aes(x=Year, y=Difference, colour = Corpus)) + geom_smooth()+ ylim(-200, 200) + labs(title="Out-Domain: Test subword-based", x="True Year", y="Predicted Year - True Year")
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# Warning message:
# “Removed 68 rows containing non-finite values (stat_smooth).”
# plot without title

# %%
ggsave("label_out-domain_test_exp3b.png")
# Out:
# Saving 7 x 7 in image
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# Warning message:
# “Removed 68 rows containing non-finite values (stat_smooth).”

# %%
DTA_train <- read.csv("/Volumes/Korpora/Exp2_results/DTA_Exp2_Reg12_Train_results.csv",sep=";", header=T)
DTA_val <- read.csv("/Volumes/Korpora/Exp2_results/DTA_Exp2_Reg12_Val_results.csv",sep=";", header=T)
DTA_test <- read.csv("/Volumes/Korpora/Exp2_results/DTA_Exp2_Reg12_Test_results.csv",sep=";", header=T)

DTA_GERMANC_val <- read.csv("/Volumes/Korpora/Exp2_results/DTA_over_GERMANC_Exp2_Reg12_Val_results.csv",sep=";", header=T)
DTA_GERMANC_test <- read.csv("/Volumes/Korpora/Exp2_results/DTA_over_GERMANC_Exp2_Reg12_Test_results.csv",sep=";", header=T)

# %%
GERMANC_train <- read.csv("/Volumes/Korpora/Exp2_results/GERMANC_Exp2_Reg12_train_results.csv",sep=";", header=T)
GERMANC_val <- read.csv("/Volumes/Korpora/Exp2_results/GERMANC_Exp2_Reg12_val_results.csv",sep=";", header=T)
GERMANC_test <- read.csv("/Volumes/Korpora/Exp2_results/GERMANC_Exp2_Reg12_test_results.csv",sep=";", header=T)

GERMANC_DTA_val <- read.csv("/Volumes/Korpora/Exp2_results/GERMANC_over_DTA_Exp2_Reg12_val_results.csv",sep=";", header=T)

GERMANC_DTA_test <- read.csv("/Volumes/Korpora/Exp2_results/GERMANC_over_DTA_Exp2_Reg12_test_results.csv",sep=";", header=T)

# %%
ARCHER_train <- read.csv("/Volumes/Korpora/Exp2_results/ARCHER_Exp2_Reg12_train_results.csv",sep=";", header=T)
ARCHER_val <- read.csv("/Volumes/Korpora/Exp2_results/ARCHER_Exp2_Reg12_val_results.csv",sep=";", header=T)
ARCHER_test <- read.csv("/Volumes/Korpora/Exp2_results/ARCHER_Exp2_Reg12_test_results.csv",sep=";", header=T)

ARCHER_CLMET_val <- read.csv("/Volumes/Korpora/Exp2_results/ARCHER_over_CLMET_Exp2_Reg12_val_results.csv",sep=";", header=T)

ARCHER_CLMET_test <- read.csv("/Volumes/Korpora/Exp2_results/ARCHER_over_CLMET_Exp2_Reg12_test_results.csv",sep=";", header=T)

# %%
CLMET_train <- read.csv("/Volumes/Korpora/Exp2_results/CLMET_Exp2_Reg12_train_results.csv",sep=";", header=T)
CLMET_val <- read.csv("/Volumes/Korpora/Exp2_results/CLMET_Exp2_Reg12_val_results.csv",sep=";", header=T)
CLMET_test <- read.csv("/Volumes/Korpora/Exp2_results/CLMET_Exp2_Reg12_test_results.csv",sep=";", header=T)

CLMET_ARCHER_val <- read.csv("/Volumes/Korpora/Exp2_results/CLMET_over_ARCHER_Exp2_Reg12_val_results.csv",sep=";", header=T)

CLMET_ARCHER_test <- read.csv("/Volumes/Korpora/Exp2_results/CLMET_over_ARCHER_Exp2_Reg12_test_results.csv",sep=";", header=T)

# %%
DTA_train_highest_features = select(DTA_train, 'feature', 'weight_value') %>%
    filter(!is.na(weight_value)) %>%
    group_by(feature) %>%
    summarise(avg=mean(weight_value)) %>%
    arrange(desc(avg)) %>%
    top_n(-10, avg)

# %%
DTA_train_highest_features
# Out:
#    feature avg
# 1  we       -219168.1
# 2  et       -226031.9
# 3  me       -232332.2
# 4  uͤ        -328309.3
# 5  er       -356217.7
# 6  in       -384587.2
# 7  an       -460280.1
# 8  ic       -526219.3
# 9  de      -1186313.5
# 10 en      -4783351.7

# %%
DTA_val_highest_features = select(DTA_val, 'feature', 'weight_value') %>%
    filter(!is.na(weight_value)) %>%
    group_by(feature) %>%
    summarise(avg=mean(weight_value)) %>%
    arrange(desc(avg)) %>%
    top_n(-10, avg)

# %%
DTA_val_highest_features
# Out:
#    feature avg
# 1  we       -170878.7
# 2  di       -178604.2
# 3  me       -187277.4
# 4  uͤ        -211094.0
# 5  er       -284927.3
# 6  in       -335696.3
# 7  an       -419405.0
# 8  ic       -420697.3
# 9  de       -973845.7
# 10 en      -3770597.3

# %%
DTA_test_highest_features = select(DTA_test, 'feature', 'weight_value') %>%
    filter(!is.na(weight_value)) %>%
    group_by(feature) %>%
    summarise(avg=mean(weight_value)) %>%
    arrange(desc(avg)) %>%
    top_n(-10, avg)

# %%
DTA_test_highest_features
# Out:
#    feature avg
# 1  we       -129094.8
# 2  di       -138810.1
# 3  me       -147403.8
# 4  er       -221977.1
# 5  uͤ        -234090.9
# 6  in       -239683.3
# 7  an       -306872.8
# 8  ic       -331376.9
# 9  de       -745069.7
# 10 en      -3094622.7

# %%
DTA_GERMANC_val_highest_features = select(DTA_GERMANC_val, 'feature', 'weight_value') %>%
    filter(!is.na(weight_value)) %>%
    group_by(feature) %>%
    summarise(avg=mean(weight_value)) %>%
    arrange(desc(avg)) %>%
    top_n(-10, avg)

DTA_GERMANC_val_highest_features
# Out:
#    feature avg
# 1  me        -64.65823
# 2  et        -66.77915
# 3  es        -68.41350
# 4  er        -85.51927
# 5  in        -91.24101
# 6  uͤ        -101.72525
# 7  an       -118.93639
# 8  ic       -153.62961
# 9  de       -252.50063
# 10 en      -1172.50951

# %%
DTA_GERMANC_test_highest_features = select(DTA_GERMANC_test, 'feature', 'weight_value') %>%
    filter(!is.na(weight_value)) %>%
    group_by(feature) %>%
    summarise(avg=mean(weight_value)) %>%
    arrange(desc(avg)) %>%
    top_n(-10, avg)

DTA_GERMANC_test_highest_features
# Out:
#    feature avg
# 1  es        -50.84563
# 2  et        -56.57506
# 3  uͤ         -76.40580
# 4  me        -76.46707
# 5  er        -77.06266
# 6  in        -88.52086
# 7  an       -102.11598
# 8  ic       -173.21855
# 9  de       -228.21933
# 10 en      -1059.70439

# %%
GERMANC_train_highest_features = select(GERMANC_train, 'feature', 'weight_value') %>%
    filter(!is.na(weight_value)) %>%
    group_by(feature) %>%
    summarise(avg=mean(weight_value)) %>%
    arrange(desc(avg)) %>%
    top_n(-10, avg)

GERMANC_train_highest_features
# Out:
#    feature avg
# 1  in         505.2632
# 2  st         447.6602
# 3  ch         443.8312
# 4  te        -978.1609
# 5  ic       -2017.3094
# 6  ge       -2163.2038
# 7  he       -2772.3482
# 8  be       -3595.4200
# 9  se       -8153.9921
# 10 nd      -11423.2749

# %%
GERMANC_val_highest_features = select(GERMANC_val, 'feature', 'weight_value') %>%
    filter(!is.na(weight_value)) %>%
    group_by(feature) %>%
    summarise(avg=mean(weight_value)) %>%
    arrange(desc(avg)) %>%
    top_n(-10, avg)

GERMANC_val_highest_features
# Out:
#    feature avg
# 1  in         535.8637
# 2  st         494.6257
# 3  ch         441.1438
# 4  te       -1051.5982
# 5  ic       -1971.3530
# 6  ge       -2330.9807
# 7  he       -3011.8814
# 8  be       -3693.9967
# 9  se       -9485.9945
# 10 nd      -13689.7830

# %%
GERMANC_test_highest_features = select(GERMANC_test, 'feature', 'weight_value') %>%
    filter(!is.na(weight_value)) %>%
    group_by(feature) %>%
    summarise(avg=mean(weight_value)) %>%
    arrange(desc(avg)) %>%
    top_n(-10, avg)

GERMANC_test_highest_features
# Out:
#    feature avg
# 1  in         519.8880
# 2  st         506.0378
# 3  ch         465.0533
# 4  te        -972.7010
# 5  ge       -1905.4139
# 6  ic       -2222.7155
# 7  he       -2431.8157
# 8  be       -3247.9871
# 9  se       -6608.8179
# 10 nd      -11867.9146

# %%
GERMANC_DTA_val_highest_features = select(GERMANC_DTA_val, 'feature', 'weight_value') %>%
    filter(!is.na(weight_value)) %>%
    group_by(feature) %>%
    summarise(avg=mean(weight_value)) %>%
    arrange(desc(avg)) %>%
    top_n(-10, avg)

GERMANC_DTA_val_highest_features
# Out:
#    feature avg
# 1  ch        1487913.092
# 2  st         321822.374
# 3  <BIAS>       1694.122
# 4  te       -4049242.225
# 5  se       -4345151.267
# 6  ic       -5398327.260
# 7  ge       -6994654.971
# 8  he       -9505712.110
# 9  be      -11905617.100
# 10 nd      -39857143.610

# %%
GERMANC_DTA_test_highest_features = select(GERMANC_DTA_test, 'feature', 'weight_value') %>%
    filter(!is.na(weight_value)) %>%
    group_by(feature) %>%
    summarise(avg=mean(weight_value)) %>%
    arrange(desc(avg)) %>%
    top_n(-10, avg)

GERMANC_DTA_test_highest_features
# Out:
#    feature avg
# 1  ch        1129626.659
# 2  st         335796.955
# 3  <BIAS>       1694.122
# 4  te       -2965928.664
# 5  ic       -4252180.100
# 6  ge       -5612622.956
# 7  se       -6758012.159
# 8  he       -7160921.262
# 9  be       -9683034.660
# 10 nd      -31798943.737

# %%
ARCHER_train_highest_features = select(ARCHER_train, 'feature', 'weight_value') %>%
    filter(!is.na(weight_value)) %>%
    group_by(feature) %>%
    summarise(avg=mean(weight_value)) %>%
    arrange(desc(avg)) %>%
    top_n(-10, avg)

ARCHER_train_highest_features
# Out:
#    feature avg
# 1  se       -2335.583
# 2  ed       -2432.134
# 3  ou       -2448.798
# 4  hi       -2975.621
# 5  or       -3013.339
# 6  at       -3374.508
# 7  in       -4886.405
# 8  th       -6471.807
# 9  nd       -7047.583
# 10 er      -12116.704

# %%
ARCHER_val_highest_features = select(ARCHER_val, 'feature', 'weight_value') %>%
    filter(!is.na(weight_value)) %>%
    group_by(feature) %>%
    summarise(avg=mean(weight_value)) %>%
    arrange(desc(avg)) %>%
    top_n(-10, avg)

ARCHER_val_highest_features
# Out:
#    feature avg
# 1  se       -2009.163
# 2  ou       -2215.347
# 3  ed       -2388.927
# 4  or       -2879.869
# 5  hi       -2998.690
# 6  at       -3171.773
# 7  in       -4947.104
# 8  th       -5983.033
# 9  nd       -6784.988
# 10 er      -11553.890

# %%
ARCHER_test_highest_features = select(ARCHER_test, 'feature', 'weight_value') %>%
    filter(!is.na(weight_value)) %>%
    group_by(feature) %>%
    summarise(avg=mean(weight_value)) %>%
    arrange(desc(avg)) %>%
    top_n(-10, avg)

ARCHER_test_highest_features
# Out:
#    feature avg
# 1  se       -2391.415
# 2  ed       -2552.473
# 3  ou       -2600.184
# 4  hi       -3001.442
# 5  or       -3233.854
# 6  at       -3659.127
# 7  in       -5068.664
# 8  th       -6786.854
# 9  nd       -7422.450
# 10 er      -13223.404

# %%
ARCHER_CLMET_val_highest_features = select(ARCHER_CLMET_val, 'feature', 'weight_value') %>%
    filter(!is.na(weight_value)) %>%
    group_by(feature) %>%
    summarise(avg=mean(weight_value)) %>%
    arrange(desc(avg)) %>%
    top_n(-10, avg)

ARCHER_CLMET_val_highest_features
# Out:
#    feature avg
# 1  of       -6036556
# 2  se       -6093321
# 3  ed       -6523851
# 4  or       -8088060
# 5  at       -8724296
# 6  hi      -10838707
# 7  in      -13108903
# 8  th      -17807518
# 9  nd      -17811259
# 10 er      -34346611

# %%
ARCHER_CLMET_test_highest_features = select(ARCHER_CLMET_test, 'feature', 'weight_value') %>%
    filter(!is.na(weight_value)) %>%
    group_by(feature) %>%
    summarise(avg=mean(weight_value)) %>%
    arrange(desc(avg)) %>%
    top_n(-10, avg)

ARCHER_CLMET_test_highest_features
# Out:
#    feature avg
# 1  ed      -15546644
# 2  se      -17010264
# 3  ou      -17250017
# 4  or      -18526360
# 5  at      -22322619
# 6  hi      -26883940
# 7  in      -28560670
# 8  th      -39420923
# 9  nd      -40571800
# 10 er      -83380486

# %%
CLMET_train_highest_features = select(CLMET_train, 'feature', 'weight_value') %>%
    filter(!is.na(weight_value)) %>%
    group_by(feature) %>%
    summarise(avg=mean(weight_value)) %>%
    arrange(desc(avg)) %>%
    top_n(-10, avg)

CLMET_train_highest_features
# Out:
#    feature avg
# 1  re        255616.556
# 2  <BIAS>      1837.658
# 3  of        -32140.289
# 4  ed        -59895.309
# 5  ou       -362591.391
# 6  on       -694150.352
# 7  en      -1452416.773
# 8  nd      -1653361.207
# 9  er      -4014452.581
# 10 th      -4842440.022

# %%
CLMET_val_highest_features = select(CLMET_val, 'feature', 'weight_value') %>%
    filter(!is.na(weight_value)) %>%
    group_by(feature) %>%
    summarise(avg=mean(weight_value)) %>%
    arrange(desc(avg)) %>%
    top_n(-10, avg)

CLMET_val_highest_features
# Out:
#    feature avg
# 1  re        124033.541
# 2  <BIAS>      1837.658
# 3  of         -8777.361
# 4  ed        -23375.686
# 5  ou       -248987.060
# 6  on       -400814.384
# 7  nd       -680349.574
# 8  en       -768775.535
# 9  th      -2165425.962
# 10 er      -2279281.396

# %%
CLMET_test_highest_features = select(CLMET_test, 'feature', 'weight_value') %>%
    filter(!is.na(weight_value)) %>%
    group_by(feature) %>%
    summarise(avg=mean(weight_value)) %>%
    arrange(desc(avg)) %>%
    top_n(-10, avg)

CLMET_test_highest_features
# Out:
#    feature avg
# 1  re        298135.213
# 2  <BIAS>      1837.658
# 3  of        -19471.639
# 4  ed        -55705.358
# 5  ou       -775516.748
# 6  on       -941587.506
# 7  nd      -1549750.474
# 8  en      -1883668.085
# 9  th      -4793654.449
# 10 er      -5533226.965

# %%
CLMET_ARCHER_val_highest_features = select(CLMET_ARCHER_val, 'feature', 'weight_value') %>%
    filter(!is.na(weight_value)) %>%
    group_by(feature) %>%
    summarise(avg=mean(weight_value)) %>%
    arrange(desc(avg)) %>%
    top_n(-10, avg)

CLMET_ARCHER_val_highest_features
# Out:
#    feature avg
# 1  ha        77.543667
# 2  re        44.636924
# 3  of        -2.858050
# 4  ed        -8.559793
# 5  ou       -99.596339
# 6  on      -125.986080
# 7  en      -254.140851
# 8  nd      -259.171120
# 9  th      -727.547446
# 10 er      -766.729718

# %%
CLMET_ARCHER_test_highest_features = select(CLMET_ARCHER_test, 'feature', 'weight_value') %>%
    filter(!is.na(weight_value)) %>%
    group_by(feature) %>%
    summarise(avg=mean(weight_value)) %>%
    arrange(desc(avg)) %>%
    top_n(-10, avg)

CLMET_ARCHER_test_highest_features
# Out:
#    feature avg
# 1  ha        86.961011
# 2  re        52.687063
# 3  of        -3.258827
# 4  ed        -9.145794
# 5  ou      -116.897623
# 6  on      -145.275721
# 7  en      -272.550926
# 8  nd      -283.520699
# 9  th      -825.293567
# 10 er      -877.520595
