# %% [markdown]
# **Experiment 3: Support Vector Regression**
#
# *Background*: Experiment 2 shows that linear regression with 215 features does not overfit anymore, but the model does not fit the beginning and the end of the timerange. Support vector regression maps all points to a higher dimensional space, which could help with fit (cf. https://scikit-learn.org/stable/modules/svm.html)
#
# Subwords worked well for some corpora, but for others, bag-of-words worked better.
#
#
#
# *Strategies*:
#
# - use support vector machines
# - Use a BPE-transformer to train on subwords (Sennrich2016)
# - use bag-of-word approach
#
# *Relevance*:
#
# - Subwords might increase the amount of generalization, and minimize the vocabulary used at the same time.
# - higher dimension might help with fit
#
# *Success criteria*:
#
# - Consistent findings over training-, test- and validation set
# - predicted year is not more than ten years away from the true year
#
# *Corpora*:
#
# - DTA
# - ARCHER
# - CLMET
# - GERMANC
#
# *Result*:
#
# -
# ***Baselines to beat (Exp. 1b)***:
#
# *MSE DTA Train*: 2259.8 | 2755.29 | 4989.51
#
# *MSE DTA Val*: 3202.51 | 3050.20 | 4577.19
#
# *MSE DTA Test*: 4504.35 | 3103.35 | 4288.83
#
# *MSE over GERMANC val*: 3700.60 | 4384.34 | 3829.78
#
# *MSE over GERMANC test*: 3565.05 | 4281.22 | 3724.79
#
# Setup:
#
# - RGB kernel
# - SVR
# - Bag-of-Words
# - select 150 kbest
#
# ----------------------------------------------------------------------------------------------------------------------
#
# *MSE CLMET Train*: 1346.26 | 2541.43 | 3135.46
#
# *MSE CLMET Val*: 2727.37 | 2702.58 | 3176.05
#
# *MSE CLMET Test*: 4315.18 | 3757.33 | 3404.04
#
# *MSE over ARCHER Val*: 10212.14 | 10004.50 | 10109.93
#
# *MSE over ARCHER Test*: 9784.28 | 9657.31 | 9719.35
#
# Setup:
# - RGB kernel
# - SVR
# - Bag-of-Words
# - select 32 kbest
#
# ----------------------------------------------------------------------------------------------------------------------
#
# *MSE ARCHER Train*: 3555.68 | 4281.68 | 8603.07
#
# *MSE ARCHER Val*: 4843.06 | 5276.70 | 8916.03
#
# *MSE ARCHER Test*: 4939.51 | 4770.15 | 8495.80
#
# *MSE over CLMET Val*: 6437126.77 | 5256255.22 | 3205.40
#
# *MSE over CLMET Test*: 6689227.44 | 10656247.10 |3673.11
#
# Setup:
#
# - RGB kernel
# - SVR
# - Bag-of-Words
# - select 130 kbest
#
# ----------------------------------------------------------------------------------------------------------------------
#
# *MSE GERMANC Train*: 348.830 | 1215.24 | 737.67
#
# *MSE GERMANC Val*: 398.94 | 1845.08 | 819.97
#
# *MSE GERMANC Test*: 649.33 | 1448.88 | 792.35
#
# *MSE over DTA val*: 8400009.85 | 25187766.76 | 9955.60
#
# *MSE over DTA test*: 21896163.78 | 18349238.65 | 8958.89
#
# Setup:
#
# - Bag-of-Words
# - selected 22 k-best

# %%
import pandas as pd
import numpy as np
import nltk

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_selection import SelectKBest , f_regression
from sklearn import svm
from sklearn.metrics import mean_squared_error
import sklearn.utils
from sklearn.preprocessing import FunctionTransformer

from Selfwritten_modules.SubwordTransformer import SubwordTransformer

import re

import eli5
from eli5.sklearn import PermutationImportance
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
#build tokenizer that just substitutes '[' and ']' with ','
def tokenizer_word(doc):
    doc = re.sub('[(\[+)|(\]+)]', '', doc)
    doc = re.split(',', doc)
    return doc

# %%
# Code example: https://stackoverflow.com/questions/39839112/the-easiest-way-for-getting-feature-names-after-running-selectkbest-in-scikit-le
def features_to_names(features, feature_names):
    features_selected = []

    for bool, feature in zip(features, feature_names):
        if bool:
            features_selected.append(feature)
    return features_selected

# %%
#function for assembling predictions in order to find out how features are weighted

def collect_predictions(dataset, classifier,vectorizer, feature_names, pipeline):
    predictions = eli5.explain_weights_df(classifier,vec=vectorizer, feature_names=feature_names)
    
    predictions = predictions.drop(['target'], axis=1)
    
    
    predictions['YEAR'] = 0
    
    indexes = dataset.index.values
    
    

    for index in indexes:
        
        pred = eli5.explain_prediction_df(classifier, dataset[index], vec=vectorizer, feature_names=feature_names)
        
        source_text = pd.DataFrame([[dataset[index]]])
        
        year_pred = pipeline.predict(source_text[0])
        pred['weight_value'] = pred['weight'] * pred['value']
        pred['instance'] = index
        
        pred = pred.drop(['target','value'], axis=1)
        
    
        pred['YEAR'] = np.round(year_pred[0])
    
        predictions = pd.concat([predictions, pred])
        
    
    
    
    return predictions.dropna()

# %%
train_full = pd.read_csv('/Volumes/Korpora/Train/DTA_train_tokenized.csv', sep=';')
val_full = pd.read_csv('/Volumes/Korpora/Val/DTA_val_tokenized.csv', sep=';')
test_full = pd.read_csv('/Volumes/Korpora/Test/DTA_test_tokenized.csv', sep=';')

# %%
print('Length train set: ',len(train_full))
print('Length validation set: ', len(val_full))
print('Length test set: ', len(test_full))
# Out:
# Length train set:  899
# Length validation set:  225
# Length test set:  281

# %%
train_x = train_full['Text']
train_y = train_full['Publication_year']

val_x = val_full['Text']
val_y = val_full['Publication_year']

test_x = test_full['Text']
test_y = test_full['Publication_year']

# %% [markdown]
# **Try SVR**

# %%
reg_1 = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 800)),
                    ('feature_selector', SelectKBest(f_regression, k='all')),
                         ('svr', svm.SVR())
                        ])

# %%
reg_1.fit(train_x, train_y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/svm/_base.py:231: ConvergenceWarning: Solver terminated early (max_iter=1000000000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=800,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x116ee2560>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k='all',
#                              score_func=<function f_regression at 0x116805a70>)),
#                 ('svr',
#                  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                      gamma='scale', kernel='linear', max_iter=1000000000,
#                      shrinking=True, tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_1.predict(train_x)
mean_squared_error(train_y, y_pred_train)
# Out:
# 62530.04426686872

# %%
y_pred_val = reg_1.predict(val_x)

mean_squared_error(val_y, y_pred_val)
# Out:
# 75321.94842239987

# %%
reg_2 = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 400)),
                    ('feature_selector', SelectKBest(f_regression, k='all')),
                         ('svr', svm.SVR())
                        ])

# %%
reg_2.fit(train_x, train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=400,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x1169d3560>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k='all',
#                              score_func=<function f_regression at 0x1162faa70>)),
#                 ('svr',
#                  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                      gamma='scale', kernel='rbf', max_iter=-1, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_2.predict(train_x)
mean_squared_error(train_y, y_pred_train)
# Out:
# 5088.6607164913485

# %%
y_pred_val = reg_2.predict(val_x)
mean_squared_error(val_y, y_pred_val)
# Out:
# 4660.419547783548

# %%
reg_3 = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 800)),
                    ('feature_selector', SelectKBest(f_regression, k=100)),
                         ('svr', svm.SVR())
                        ])

# %%
reg_3.fit(train_x, train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=800,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x1169d3560>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k=100,
#                              score_func=<function f_regression at 0x1162faa70>)),
#                 ('svr',
#                  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                      gamma='scale', kernel='rbf', max_iter=-1, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_3.predict(train_x)
mean_squared_error(train_y, y_pred_train)
# Out:
# 4983.908350759601

# %%
y_pred_val = reg_3.predict(val_x)
mean_squared_error(val_y, y_pred_val)
# Out:
# 4571.6984857298385

# %%
reg_4 = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 800)),
                    ('feature_selector', SelectKBest(f_regression, k=50)),
                         ('svr', svm.SVR())
                        ])

# %%
reg_4.fit(train_x, train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=800,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x1169d3560>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k=50,
#                              score_func=<function f_regression at 0x1162faa70>)),
#                 ('svr',
#                  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                      gamma='scale', kernel='rbf', max_iter=-1, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_3.predict(train_x)
mean_squared_error(train_y, y_pred_train)
# Out:
# 4983.908350759601

# %%
y_pred_val = reg_3.predict(val_x)
mean_squared_error(val_y, y_pred_val)
# Out:
# 4571.6984857298385

# %%
reg_5 = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 800)),
                    ('feature_selector', SelectKBest(f_regression, k=150)),
                         ('svr', svm.SVR(kernel='poly', degree=5))
                        ])

# %%
reg_5.fit(train_x, train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=800,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x12491a950>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k=150,
#                              score_func=<function f_regression at 0x124240a70>)),
#                 ('svr',
#                  SVR(C=1.0, cache_size=200, coef0=0.0, degree=5, epsilon=0.1,
#                      gamma='scale', kernel='poly', max_iter=-1, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_3.predict(train_x)
mean_squared_error(train_y, y_pred_train)
# Out:
# 723614.6055945167

# %%
y_pred_val = reg_3.predict(val_x)
mean_squared_error(val_y, y_pred_val)
# Out:
# 1389410.8249968216

# %% [markdown]
# **Try NuSVR**

# %%
reg_1 = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 800)),
                    ('feature_selector', SelectKBest(f_regression, k='all')),
                         ('svr', svm.NuSVR())
                        ])

# %%
reg_1.fit(train_x, train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=800,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x1169d3560>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k='all',
#                              score_func=<function f_regression at 0x1162faa70>)),
#                 ('svr',
#                  NuSVR(C=1.0, cache_size=200, coef0=0.0, degree=3,
#                        gamma='scale', kernel='rbf', max_iter=-1, nu=0.5,
#                        shrinking=True, tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_1.predict(train_x)
mean_squared_error(train_y, y_pred_train)
# Out:
# 5120.97448729449

# %%
y_pred_val = reg_1.predict(val_x)
mean_squared_error(val_y, y_pred_val)
# Out:
# 4695.405958943123

# %%
reg_2 = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 800)),
                    ('feature_selector', SelectKBest(f_regression, k=100)),
                         ('svr', svm.NuSVR())
                        ])

# %%
reg_2.fit(train_x, train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=800,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x1169d3560>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k=100,
#                              score_func=<function f_regression at 0x1162faa70>)),
#                 ('svr',
#                  NuSVR(C=1.0, cache_size=200, coef0=0.0, degree=3,
#                        gamma='scale', kernel='rbf', max_iter=-1, nu=0.5,
#                        shrinking=True, tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_2.predict(train_x)
mean_squared_error(train_y, y_pred_train)
# Out:
# 4998.2428364029665

# %%
y_pred_val = reg_2.predict(val_x)
mean_squared_error(val_y, y_pred_val)
# Out:
# 4578.414062910382

# %% [markdown]
# **Try linearSVR**

# %%
reg_1 = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 800)),
                    ('feature_selector', SelectKBest(f_regression, k='all')),
                         ('svr', svm.LinearSVR())
                        ])

# %%
reg_1.fit(train_x, train_y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=800,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x1169d3560>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k='all',
#                              score_func=<function f_regression at 0x1162faa70>)),
#                 ('svr',
#                  LinearSVR(C=1.0, dual=True, epsilon=0.0, fit_intercept=True,
#                            intercept_scaling=1.0, loss='epsilon_insensitive',
#                            max_iter=1000, random_state=None, tol=0.0001,
#                            verbose=0))],
#          verbose=False)

# %%
y_pred_train = reg_1.predict(train_x)
mean_squared_error(train_y, y_pred_train)
# Out:
# 62530.04426686872

# %%
y_pred_val = reg_1.predict(val_x)
mean_squared_error(val_y, y_pred_val)
# Out:
# 75321.94842239987

# %% [markdown]
# Reg 5 with SVR works best

# %%
reg_5 = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 800)),
                    ('feature_selector', SelectKBest(f_regression, k=150)),
                         ('svr', svm.SVR())
                        ])

# %%
reg_5.fit(train_x, train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=800,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x11f3aa680>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k=150,
#                              score_func=<function f_regression at 0x11eccca70>)),
#                 ('svr',
#                  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                      gamma='scale', kernel='rbf', max_iter=-1, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_5.predict(train_x)
mean_squared_error(train_y, y_pred_train)
# Out:
# 4989.50795950559

# %%
y_pred_val = reg_5.predict(val_x)
mean_squared_error(val_y, y_pred_val)
# Out:
# 4577.185764875978

# %%
y_pred_test = reg_5.predict(test_x)
mean_squared_error(test_y, y_pred_test)
# Out:
# 4288.834314224981

# %%
transformator = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 800)),
                    ('feature_selector', SelectKBest(f_regression, k=150))
                        ])

# %%
train_transform = transformator.fit_transform(train_x, train_y)

# %%
train_transform = train_transform.toarray()

# %%
perm = PermutationImportance(reg_5['svr']).fit(train_transform, y_pred_train)

# %%
features = transformator['feature_selector'].get_support()
feature_names = transformator['unigram_vectorizer'].get_feature_names()

features_selected = features_to_names(features, feature_names)

# %%
eli5.explain_weights(perm, feature_names=features_selected)
# Out:
# Explanation(estimator="PermutationImportance(cv='prefit',\n                      estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,\n                                    epsilon=0.1, gamma='scale', kernel='rbf',\n                                    max_iter=-1, shrinking=True, tol=0.001,\n                                    verbose=False),\n                      n_iter=5, random_state=None, refit=True, scoring=None)", description="\nFeature importances, computed as a decrease in score when feature\nvalues are permuted (i.e. become noise). This is also known as \npermutation importance.\n\nIf feature importances are computed on the same data as used for training, \nthey don't reflect importance of features for generalization. Use a held-out\ndataset if you want generalization feature importances.\n", error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature="'", weight=0.4823892582307859, std=0.021807631760793218, value=None), FeatureWeight(feature=" '", weight=0.47564912893088673, std=0.004379978092933814, value=None), FeatureWeight(feature=" 'der'", weight=0.01283324184355943, std=0.0013895882910242474, value=None), FeatureWeight(feature=" 'die'", weight=0.010081096384521792, std=0.0007170746333725204, value=None), FeatureWeight(feature=" ''", weight=0.005988373145124082, std=0.0010784556827109547, value=None), FeatureWeight(feature=" 'in'", weight=0.0010407367052931882, std=0.00025146859556812533, value=None), FeatureWeight(feature=" 'des'", weight=0.0005800856642851126, std=4.558399176316715e-05, value=None), FeatureWeight(feature=" 'den'", weight=0.00035862824734820273, std=2.272215438762522e-05, value=None), FeatureWeight(feature=" 'er'", weight=0.0002997289963085903, std=3.4119105019004475e-05, value=None), FeatureWeight(feature=" 'nicht'", weight=0.0002879066055465618, std=0.0001338845524068106, value=None), FeatureWeight(feature=" 'ein'", weight=0.0002395612824207749, std=3.4882602082593806e-05, value=None), FeatureWeight(feature=" 'man'", weight=0.00023063446883739847, std=4.5487358208935346e-05, value=None), FeatureWeight(feature=" ':'", weight=0.0002295768601186632, std=2.4771291271500043e-05, value=None), FeatureWeight(feature=" 'von'", weight=0.00020318110208792373, std=5.147800949053176e-05, value=None), FeatureWeight(feature=" 'auch'", weight=0.00013413769573737965, std=3.956274027928396e-05, value=None), FeatureWeight(feature=" 'das'", weight=0.0001273785986686704, std=4.004627841546897e-05, value=None), FeatureWeight(feature=" 'oder'", weight=0.00012094696723845555, std=2.029759992919885e-05, value=None), FeatureWeight(feature=" 'auf'", weight=0.00010617495174634062, std=1.0432570803914e-05, value=None), FeatureWeight(feature=" 'ich'", weight=8.284058494978375e-05, std=9.29930728477461e-06, value=None), FeatureWeight(feature=" 'im'", weight=2.595584620657121e-05, std=2.40412539443146e-06, value=None)], remaining=130), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
DTA_train_features_Exp3 = eli5.explain_weights_df(perm, feature_names=features_selected)

# %%
val_transform = transformator.transform(val_x)

# %%
val_transform = val_transform.toarray()

# %%
perm = PermutationImportance(reg_5['svr']).fit(val_transform, y_pred_val)

# %%
eli5.explain_weights(perm, feature_names=features_selected)
# Out:
# Explanation(estimator="PermutationImportance(cv='prefit',\n                      estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,\n                                    epsilon=0.1, gamma='scale', kernel='rbf',\n                                    max_iter=-1, shrinking=True, tol=0.001,\n                                    verbose=False),\n                      n_iter=5, random_state=None, refit=True, scoring=None)", description="\nFeature importances, computed as a decrease in score when feature\nvalues are permuted (i.e. become noise). This is also known as \npermutation importance.\n\nIf feature importances are computed on the same data as used for training, \nthey don't reflect importance of features for generalization. Use a held-out\ndataset if you want generalization feature importances.\n", error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature="'", weight=0.48394148390558833, std=0.04239712330659884, value=None), FeatureWeight(feature=" '", weight=0.472646787861961, std=0.01853163068562962, value=None), FeatureWeight(feature=" ''", weight=0.011204177920963421, std=0.001385127160146753, value=None), FeatureWeight(feature=" 'der'", weight=0.009910884646365003, std=0.001032819526207806, value=None), FeatureWeight(feature=" 'die'", weight=0.009101511320519595, std=0.0009971165905242475, value=None), FeatureWeight(feature=" 'in'", weight=0.0006473132265578218, std=0.00028416189748553636, value=None), FeatureWeight(feature=" 'des'", weight=0.0004959775581808046, std=4.3326501227990724e-05, value=None), FeatureWeight(feature=" 'er'", weight=0.0003803641803772573, std=6.955078356624415e-05, value=None), FeatureWeight(feature=" 'ich'", weight=0.0002515364123970798, std=2.7133817399727354e-05, value=None), FeatureWeight(feature=" 'ein'", weight=0.00019025564028614107, std=3.4243838350986875e-05, value=None), FeatureWeight(feature=" 'nicht'", weight=0.0001708219305495584, std=5.833096955701295e-05, value=None), FeatureWeight(feature=" ':'", weight=0.00016435519834632207, std=1.9363502265370768e-05, value=None), FeatureWeight(feature=" 'von'", weight=0.00015802529624378003, std=5.0491432153695846e-05, value=None), FeatureWeight(feature=" 'man'", weight=0.00012925168962258927, std=2.293001978111564e-05, value=None), FeatureWeight(feature=" 'den'", weight=0.00012658933936691153, std=5.112185489538525e-05, value=None), FeatureWeight(feature=" 'oder'", weight=8.153445565735051e-05, std=5.810534149531173e-05, value=None), FeatureWeight(feature=" 'auf'", weight=6.924713647371572e-05, std=1.1328639853599384e-05, value=None), FeatureWeight(feature=" 'auch'", weight=6.172938660051753e-05, std=1.4966013826207478e-05, value=None), FeatureWeight(feature=" 'das'", weight=3.2681369084586184e-05, std=3.15345539605713e-06, value=None), FeatureWeight(feature=" 'eine'", weight=2.2479224876903458e-05, std=4.659881046520082e-06, value=None)], remaining=130), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
DTA_val_features_Exp3 = eli5.explain_weights_df(perm, feature_names=features_selected)

# %%
test_transform = transformator.transform(test_x)

# %%
test_transform = test_transform.toarray()

# %%
perm = PermutationImportance(reg_5['svr']).fit(test_transform, y_pred_test)

# %%
eli5.explain_weights(perm, feature_names=features_selected)
# Out:
# Explanation(estimator="PermutationImportance(cv='prefit',\n                      estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,\n                                    epsilon=0.1, gamma='scale', kernel='rbf',\n                                    max_iter=-1, shrinking=True, tol=0.001,\n                                    verbose=False),\n                      n_iter=5, random_state=None, refit=True, scoring=None)", description="\nFeature importances, computed as a decrease in score when feature\nvalues are permuted (i.e. become noise). This is also known as \npermutation importance.\n\nIf feature importances are computed on the same data as used for training, \nthey don't reflect importance of features for generalization. Use a held-out\ndataset if you want generalization feature importances.\n", error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature=" '", weight=0.47064853536664086, std=0.025571426217696112, value=None), FeatureWeight(feature="'", weight=0.46922725317222885, std=0.03185950493467764, value=None), FeatureWeight(feature=" 'der'", weight=0.010024671253283346, std=0.00134090806800288, value=None), FeatureWeight(feature=" 'die'", weight=0.008541667679214915, std=0.0009486689366180959, value=None), FeatureWeight(feature=" ''", weight=0.006969089551038032, std=0.0011374800385388652, value=None), FeatureWeight(feature=" 'des'", weight=0.0004217027907212012, std=3.1931811892322134e-05, value=None), FeatureWeight(feature=" 'in'", weight=0.0003803958290497178, std=4.5328938272111357e-05, value=None), FeatureWeight(feature=" 'er'", weight=0.00024672213211007765, std=5.470460583125545e-05, value=None), FeatureWeight(feature=" 'ein'", weight=0.00015072733119521066, std=2.2326590402981017e-05, value=None), FeatureWeight(feature=" 'den'", weight=0.00012233491918525185, std=1.3592065586004226e-05, value=None), FeatureWeight(feature=" ':'", weight=0.0001124509152520492, std=2.3117683106339695e-05, value=None), FeatureWeight(feature=" 'von'", weight=0.00010839925725008026, std=2.3865707834676475e-05, value=None), FeatureWeight(feature=" 'nicht'", weight=0.00010304021593903201, std=2.3816568707301365e-05, value=None), FeatureWeight(feature=" 'man'", weight=7.933272888436261e-05, std=8.221189538403088e-06, value=None), FeatureWeight(feature=" 'ich'", weight=6.72624619358686e-05, std=1.7888044643084675e-05, value=None), FeatureWeight(feature=" 'das'", weight=6.476584421997167e-05, std=1.5901924622836065e-05, value=None), FeatureWeight(feature=" 'auf'", weight=6.0729221488986515e-05, std=1.056904466339046e-05, value=None), FeatureWeight(feature=" 'oder'", weight=5.410697170793455e-05, std=9.731159508534045e-06, value=None), FeatureWeight(feature=" 'auch'", weight=4.2412866221885893e-05, std=5.3990184237885105e-06, value=None), FeatureWeight(feature=" 'eine'", weight=1.3057361368029596e-05, std=2.025527169105241e-06, value=None)], remaining=130), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
DTA_test_features_Exp3 = eli5.explain_weights_df(perm, feature_names=features_selected)

# %%
y_pred_train = pd.DataFrame(y_pred_train, columns=['Predicted_y'])

diff_pred_true_train = pd.concat([y_pred_train, train_y], axis=1)

diff_pred_true_train['Difference'] = diff_pred_true_train.Predicted_y - diff_pred_true_train.Publication_year
    

y_pred_val = pd.DataFrame(y_pred_val, columns=['Predicted_y'])

diff_pred_true_val = pd.concat([y_pred_val, val_y], axis=1)

diff_pred_true_val['Difference'] = diff_pred_true_val.Predicted_y - diff_pred_true_val.Publication_year


y_pred_test = pd.DataFrame(y_pred_test, columns=['Predicted_y'])

diff_pred_true_test = pd.concat([y_pred_test, test_y], axis=1)

diff_pred_true_test['Difference'] = diff_pred_true_test.Predicted_y - diff_pred_true_test.Publication_year

# %%
diff_pred_true_train.to_csv('/Volumes/Korpora/Exp3_results/DTA_Exp3_Reg5_Labels_train.csv',sep=';')
diff_pred_true_val.to_csv('/Volumes/Korpora/Exp3_results/DTA_Exp3_Reg5_Labels_val.csv',sep=';')
diff_pred_true_test.to_csv('/Volumes/Korpora/Exp3_results/DTA_Exp3_Reg5_Labels_test.csv',sep=';')

# %%
DTA_train_features_Exp3.to_csv('/Volumes/Korpora/Exp3_results/DTA_train_features_Exp3.csv',sep=';')
DTA_val_features_Exp3.to_csv('/Volumes/Korpora/Exp3_results/DTA_val_features_Exp3.csv', sep=';')
DTA_test_features_Exp3.to_csv('/Volumes/Korpora/Exp3_results/DTA_test_features_Exp3.csv', sep=';')

# %%
GERMANC_train_full = pd.read_csv('/Volumes/Korpora/Train/GERMANC_train_tokenized.csv', sep=';')
GERMANC_val_full = pd.read_csv('/Volumes/Korpora/Val/GERMANC_val_tokenized.csv', sep=';')
GERMANC_test_full = pd.read_csv('/Volumes/Korpora/Test/GERMANC_test_tokenized.csv', sep=';')

# %%
GERMANC_train_full = GERMANC_train_full[(GERMANC_train_full.Year.str.len()== 4) & (GERMANC_train_full.Year.str.isnumeric())]

GERMANC_val_full = GERMANC_val_full[(GERMANC_val_full.Year.str.len()== 4) & (GERMANC_val_full.Year.str.isnumeric())]

GERMANC_test_full = GERMANC_test_full[(GERMANC_test_full.Year.str.len()== 4) & (GERMANC_test_full.Year.str.isnumeric())]

# %%
print('Length train set: ',len(GERMANC_train_full))
print('Length validation set: ', len(GERMANC_val_full))
print('Length test set: ', len(GERMANC_test_full))
# Out:
# Length train set:  177
# Length validation set:  40
# Length test set:  56

# %%
GERMANC_train_x = GERMANC_train_full['Text']
GERMANC_train_y = GERMANC_train_full['Year'].astype(int)

GERMANC_val_x = GERMANC_val_full['Text']
GERMANC_val_y = GERMANC_val_full['Year'].astype(int)

GERMANC_test_x = GERMANC_test_full['Text']
GERMANC_test_y = GERMANC_test_full['Year'].astype(int)

# %%
y_pred_val = reg_5.predict(GERMANC_val_x)
mean_squared_error(GERMANC_val_y, y_pred_val)
# Out:
# 3829.781853517679

# %%
y_pred_test = reg_5.predict(GERMANC_test_x)
mean_squared_error(GERMANC_test_y, y_pred_test)
# Out:
# 3724.787438465452

# %%
y_pred_val = pd.DataFrame(y_pred_val, columns=['Predicted_y'])

diff_pred_true_val = pd.concat([y_pred_val, GERMANC_val_y], axis=1)

diff_pred_true_val['Difference'] = diff_pred_true_val.Predicted_y - diff_pred_true_val.Year


y_pred_test = pd.DataFrame(y_pred_test, columns=['Predicted_y'])

diff_pred_true_test = pd.concat([y_pred_test, GERMANC_test_y], axis=1)

diff_pred_true_test['Difference'] = diff_pred_true_test.Predicted_y - diff_pred_true_test.Year

# %%
diff_pred_true_val.to_csv('/Volumes/Korpora/Exp3_results/DTA_over_GERMANC_Exp3_Reg5_Labels_val.csv',sep=';')
diff_pred_true_test.to_csv('/Volumes/Korpora/Exp3_results/DTA_over_GERMANC_Exp3_Reg5_Labels_test.csv',sep=';')

# %%
val_transform = transformator.transform(GERMANC_val_x)
val_transform = val_transform.toarray()

# %%
perm = PermutationImportance(reg_5['svr']).fit(val_transform, y_pred_val)

# %%
eli5.explain_weights(perm, feature_names=features_selected)
# Out:
# Explanation(estimator="PermutationImportance(cv='prefit',\n                      estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,\n                                    epsilon=0.1, gamma='scale', kernel='rbf',\n                                    max_iter=-1, shrinking=True, tol=0.001,\n                                    verbose=False),\n                      n_iter=5, random_state=None, refit=True, scoring=None)", description="\nFeature importances, computed as a decrease in score when feature\nvalues are permuted (i.e. become noise). This is also known as \npermutation importance.\n\nIf feature importances are computed on the same data as used for training, \nthey don't reflect importance of features for generalization. Use a held-out\ndataset if you want generalization feature importances.\n", error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature=" '", weight=0.5650129989735706, std=0.06618720966249725, value=None), FeatureWeight(feature="'", weight=0.5277608851714529, std=0.02407770979053208, value=None), FeatureWeight(feature=" ':'", weight=0.0007213603939815849, std=9.582445557165337e-05, value=None), FeatureWeight(feature=" 'ein'", weight=0.0006454062342022837, std=3.844644322126546e-05, value=None), FeatureWeight(feature=" 'er'", weight=0.00046816355613659154, std=5.583588818130267e-05, value=None), FeatureWeight(feature=" 'oder'", weight=0.0003039356209646016, std=4.6971852445701824e-05, value=None), FeatureWeight(feature=" 'in'", weight=0.00018569413688112045, std=2.2511088291664593e-05, value=None), FeatureWeight(feature=" ''", weight=0.00012739148889544526, std=1.4440284674753797e-05, value=None), FeatureWeight(feature=" 'man'", weight=0.00011642113203125248, std=1.4105998961915856e-05, value=None), FeatureWeight(feature=" 'nicht'", weight=9.700138306327766e-05, std=2.1082397525182062e-05, value=None), FeatureWeight(feature=" 'von'", weight=6.898171445453016e-05, std=9.795603310845303e-06, value=None), FeatureWeight(feature=" 'die'", weight=6.71557589118299e-05, std=1.347552247070158e-05, value=None), FeatureWeight(feature=" 'auch'", weight=4.89894348846498e-05, std=4.003286768040606e-06, value=None), FeatureWeight(feature=" 'sie'", weight=4.10327552655021e-05, std=7.850660471693327e-06, value=None), FeatureWeight(feature=" 'den'", weight=3.803110341893401e-05, std=5.248607843761681e-06, value=None), FeatureWeight(feature=" 'das'", weight=3.481601954993252e-05, std=4.1903569482590666e-06, value=None), FeatureWeight(feature=" 'der'", weight=2.9850930233243923e-05, std=4.110204380956968e-06, value=None), FeatureWeight(feature=" 'ich'", weight=2.7008207220857728e-05, std=6.620806295899906e-06, value=None), FeatureWeight(feature=" 'des'", weight=2.689660912034153e-05, std=1.6470224113120615e-06, value=None), FeatureWeight(feature=" 'wie'", weight=1.533874222159337e-05, std=1.9492210813057052e-06, value=None)], remaining=130), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
DTA_GERMANC_val_features = eli5.explain_weights_df(perm, feature_names=features_selected)

# %%
test_transform = transformator.transform(GERMANC_test_x)
test_transform = test_transform.toarray()

# %%
perm = PermutationImportance(reg_5['svr']).fit(test_transform, y_pred_test)

# %%
eli5.explain_weights(perm, feature_names=features_selected)
# Out:
# Explanation(estimator="PermutationImportance(cv='prefit',\n                      estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,\n                                    epsilon=0.1, gamma='scale', kernel='rbf',\n                                    max_iter=-1, shrinking=True, tol=0.001,\n                                    verbose=False),\n                      n_iter=5, random_state=None, refit=True, scoring=None)", description="\nFeature importances, computed as a decrease in score when feature\nvalues are permuted (i.e. become noise). This is also known as \npermutation importance.\n\nIf feature importances are computed on the same data as used for training, \nthey don't reflect importance of features for generalization. Use a held-out\ndataset if you want generalization feature importances.\n", error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature=" '", weight=0.5497052993699922, std=0.029584948040072993, value=None), FeatureWeight(feature="'", weight=0.505973281394959, std=0.037992063791343296, value=None), FeatureWeight(feature=" ''", weight=0.0003146984548506149, std=2.631667662631623e-05, value=None), FeatureWeight(feature=" ':'", weight=0.00026541147112861817, std=3.741121243830093e-05, value=None), FeatureWeight(feature=" 'er'", weight=0.0002559839796262064, std=2.2621118808882524e-05, value=None), FeatureWeight(feature=" 'oder'", weight=0.0002036612568915741, std=3.0523650272258585e-05, value=None), FeatureWeight(feature=" 'nicht'", weight=0.000172839795110602, std=1.0725241309453735e-05, value=None), FeatureWeight(feature=" 'ein'", weight=0.00012734920094932268, std=1.149785263042927e-05, value=None), FeatureWeight(feature=" 'man'", weight=0.00012436807816276207, std=1.8796052863014653e-05, value=None), FeatureWeight(feature=" 'in'", weight=0.00012282071524531978, std=2.1971016896697773e-05, value=None), FeatureWeight(feature=" 'die'", weight=0.00010771837413561247, std=8.00017691643484e-06, value=None), FeatureWeight(feature=" 'von'", weight=6.949925245327559e-05, std=6.636596286278339e-06, value=None), FeatureWeight(feature=" 'auch'", weight=5.850015014063903e-05, std=1.1308586194429243e-05, value=None), FeatureWeight(feature=" 'ich'", weight=5.1325203837859766e-05, std=3.400112813833569e-06, value=None), FeatureWeight(feature=" 'sie'", weight=4.871899077922848e-05, std=7.87564378424583e-06, value=None), FeatureWeight(feature=" 'der'", weight=4.41218167050339e-05, std=1.6868097104851544e-06, value=None), FeatureWeight(feature=" 'das'", weight=3.63282474011406e-05, std=4.288120666523331e-06, value=None), FeatureWeight(feature=" '?'", weight=3.479738692671042e-05, std=2.9373800745833905e-06, value=None), FeatureWeight(feature=" 'den'", weight=2.7707028027323942e-05, std=3.529322669167731e-06, value=None), FeatureWeight(feature=" 'was'", weight=1.8085555433167146e-05, std=1.0695590665933022e-06, value=None)], remaining=130), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
DTA_GERMANC_test_features = eli5.explain_weights_df(perm, feature_names=features_selected)

# %%
DTA_GERMANC_val_features.to_csv('/Volumes/Korpora/Exp3_results/DTA_over_GERMANC_val_features_Exp3.csv', sep=';')
DTA_GERMANC_test_features.to_csv('/Volumes/Korpora/Exp3_results/DTA_over_GERMANC_test_features_Exp3.csv', sep=';')

# %% [markdown]
# **GERMANC**

# %%
reg_5 = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 105)),
                    ('feature_selector', SelectKBest(f_regression, k=44)),
                         ('svr', svm.SVR())
                        ])

# %%
reg_5.fit(GERMANC_train_x, GERMANC_train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=105,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x11f3aa680>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k=44,
#                              score_func=<function f_regression at 0x11eccca70>)),
#                 ('svr',
#                  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                      gamma='scale', kernel='rbf', max_iter=-1, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_5.predict(GERMANC_train_x)
mean_squared_error(GERMANC_train_y, y_pred_train)
# Out:
# 745.5235419490572

# %%
y_pred_val = reg_5.predict(GERMANC_val_x)
mean_squared_error(GERMANC_val_y, y_pred_val)
# Out:
# 835.3956312421485

# %%
reg_5 = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 105)),
                    ('feature_selector', SelectKBest(f_regression, k=22)),
                         ('svr', svm.SVR())
                        ])

# %%
reg_5.fit(GERMANC_train_x, GERMANC_train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=105,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x11f3aa680>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k=22,
#                              score_func=<function f_regression at 0x11eccca70>)),
#                 ('svr',
#                  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                      gamma='scale', kernel='rbf', max_iter=-1, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_5.predict(GERMANC_train_x)
mean_squared_error(GERMANC_train_y, y_pred_train)
# Out:
# 737.6743405427411

# %%
y_pred_val = reg_5.predict(GERMANC_val_x)
mean_squared_error(GERMANC_val_y, y_pred_val)
# Out:
# 819.9692302589707

# %%
reg_5 = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 105)),
                    ('feature_selector', SelectKBest(f_regression, k=11)),
                         ('svr', svm.SVR())
                        ])

# %%
reg_5.fit(GERMANC_train_x, GERMANC_train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=105,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x11f3aa680>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k=11,
#                              score_func=<function f_regression at 0x11eccca70>)),
#                 ('svr',
#                  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                      gamma='scale', kernel='rbf', max_iter=-1, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_5.predict(GERMANC_train_x)
mean_squared_error(GERMANC_train_y, y_pred_train)
# Out:
# 737.7050912827574

# %%
y_pred_val = reg_5.predict(GERMANC_val_x)
mean_squared_error(GERMANC_val_y, y_pred_val)
# Out:
# 798.3255078309553

# %%
reg_5 = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 105)),
                    ('feature_selector', SelectKBest(f_regression, k=33)),
                         ('svr', svm.SVR())
                        ])

# %%
reg_5.fit(GERMANC_train_x, GERMANC_train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=105,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x11f3aa680>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k=33,
#                              score_func=<function f_regression at 0x11eccca70>)),
#                 ('svr',
#                  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                      gamma='scale', kernel='rbf', max_iter=-1, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_5.predict(GERMANC_train_x)
mean_squared_error(GERMANC_train_y, y_pred_train)
# Out:
# 741.7157483274672

# %%
y_pred_val = reg_5.predict(GERMANC_val_x)
mean_squared_error(GERMANC_val_y, y_pred_val)
# Out:
# 827.0194034306454

# %%
reg_5 = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 105)),
                    ('feature_selector', SelectKBest(f_regression, k=22)),
                         ('svr', svm.SVR())
                        ])

# %%
reg_5.fit(GERMANC_train_x, GERMANC_train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=105,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x117122560>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k=22,
#                              score_func=<function f_regression at 0x116a48a70>)),
#                 ('svr',
#                  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                      gamma='scale', kernel='rbf', max_iter=-1, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_5.predict(GERMANC_train_x)
mean_squared_error(GERMANC_train_y, y_pred_train)
# Out:
# 737.6743405427411

# %%
y_pred_val = reg_5.predict(GERMANC_val_x)
mean_squared_error(GERMANC_val_y, y_pred_val)
# Out:
# 819.9692302589707

# %%
y_pred_test = reg_5.predict(GERMANC_test_x)
mean_squared_error(GERMANC_test_y, y_pred_test)
# Out:
# 792.3454058965783

# %%
y_pred_train = pd.DataFrame(y_pred_train, columns=['Predicted_y'])

diff_pred_true_train = pd.concat([y_pred_train, GERMANC_train_y], axis=1)

diff_pred_true_train['Difference'] = diff_pred_true_train.Predicted_y - diff_pred_true_train.Year
    

y_pred_val = pd.DataFrame(y_pred_val, columns=['Predicted_y'])

diff_pred_true_val = pd.concat([y_pred_val, GERMANC_val_y], axis=1)

diff_pred_true_val['Difference'] = diff_pred_true_val.Predicted_y - diff_pred_true_val.Year


y_pred_test = pd.DataFrame(y_pred_test, columns=['Predicted_y'])

diff_pred_true_test = pd.concat([y_pred_test, GERMANC_test_y], axis=1)

diff_pred_true_test['Difference'] = diff_pred_true_test.Predicted_y - diff_pred_true_test.Year

# %%
diff_pred_true_train.to_csv('/Volumes/Korpora/Exp3_results/GERMANC_Exp3_Reg5_Labels_train.csv',sep=';')
diff_pred_true_val.to_csv('/Volumes/Korpora/Exp3_results/GERMANC_Exp3_Reg5_Labels_val.csv',sep=';')
diff_pred_true_test.to_csv('/Volumes/Korpora/Exp3_results/GERMANC_Exp3_Reg5_Labels_test.csv',sep=';')

# %%
transformator = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 105)),
                    ('feature_selector', SelectKBest(f_regression, k=22))
                        ])

# %%
train_transform = transformator.fit_transform(GERMANC_train_x, GERMANC_train_y)
train_transform = train_transform.toarray()

# %%
features = transformator['feature_selector'].get_support()
feature_names = transformator['unigram_vectorizer'].get_feature_names()

features_selected = features_to_names(features, feature_names)

# %%
perm = PermutationImportance(reg_5['svr']).fit(train_transform, y_pred_train)

# %%
eli5.explain_weights(perm, feature_names=features_selected)
# Out:
# Explanation(estimator="PermutationImportance(cv='prefit',\n                      estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,\n                                    epsilon=0.1, gamma='scale', kernel='rbf',\n                                    max_iter=-1, shrinking=True, tol=0.001,\n                                    verbose=False),\n                      n_iter=5, random_state=None, refit=True, scoring=None)", description="\nFeature importances, computed as a decrease in score when feature\nvalues are permuted (i.e. become noise). This is also known as \npermutation importance.\n\nIf feature importances are computed on the same data as used for training, \nthey don't reflect importance of features for generalization. Use a held-out\ndataset if you want generalization feature importances.\n", error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature="'", weight=0.5198144935673817, std=0.04329068255787555, value=None), FeatureWeight(feature=" '", weight=0.5133063212786368, std=0.04968638669805257, value=None), FeatureWeight(feature=" ':'", weight=0.0020226825747997833, std=0.0002223780036658894, value=None), FeatureWeight(feature=" 'die'", weight=0.0002808626450796714, std=1.6755913490378136e-05, value=None), FeatureWeight(feature=" 'daß'", weight=5.492585624244928e-05, std=4.104720506622915e-06, value=None), FeatureWeight(feature=" 'des'", weight=4.3146776371916215e-05, std=1.0229509802260746e-05, value=None), FeatureWeight(feature=" 'auf'", weight=3.949399086384808e-05, std=4.632233962147844e-06, value=None), FeatureWeight(feature=" 'wenn'", weight=4.768976773084077e-06, std=1.109594174904751e-06, value=None), FeatureWeight(feature=" 'eine'", weight=3.6877431727866393e-06, std=5.459557387062141e-07, value=None), FeatureWeight(feature=" 'um'", weight=2.582290283403843e-06, std=3.03003586147511e-07, value=None), FeatureWeight(feature=" 'sind'", weight=2.2218519601935327e-06, std=2.9016783949555446e-07, value=None), FeatureWeight(feature=" 'nur'", weight=1.6379179446524006e-06, std=1.702681989732476e-07, value=None), FeatureWeight(feature=" 'aus'", weight=1.6167527278287964e-06, std=4.006428607494389e-08, value=None), FeatureWeight(feature=" 'haben'", weight=1.3250966532041276e-06, std=1.498937939152677e-07, value=None), FeatureWeight(feature=" 'diese'", weight=9.724591167659113e-07, std=1.3428643777090505e-07, value=None), FeatureWeight(feature=" 'dann'", weight=9.584482025148943e-07, std=2.0737939750571356e-07, value=None), FeatureWeight(feature=" 'hier'", weight=5.622955783879391e-07, std=1.0087539458624849e-07, value=None), FeatureWeight(feature=" 'dieser'", weight=4.912499079745558e-07, std=1.391112803779964e-07, value=None), FeatureWeight(feature=" 'unter'", weight=1.8886809527440818e-07, std=3.2660638454999736e-08, value=None), FeatureWeight(feature=" 'machen'", weight=1.836367394592031e-07, std=3.0832497533504804e-08, value=None)], remaining=2), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
GERMANC_train_features = eli5.explain_weights_df(perm, feature_names=features_selected)

# %%
val_transform = transformator.transform(GERMANC_val_x)
val_transform = val_transform.toarray()

# %%
perm = PermutationImportance(reg_5['svr']).fit(val_transform, y_pred_val)
eli5.explain_weights(perm, feature_names=features_selected)
# Out:
# Explanation(estimator="PermutationImportance(cv='prefit',\n                      estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,\n                                    epsilon=0.1, gamma='scale', kernel='rbf',\n                                    max_iter=-1, shrinking=True, tol=0.001,\n                                    verbose=False),\n                      n_iter=5, random_state=None, refit=True, scoring=None)", description="\nFeature importances, computed as a decrease in score when feature\nvalues are permuted (i.e. become noise). This is also known as \npermutation importance.\n\nIf feature importances are computed on the same data as used for training, \nthey don't reflect importance of features for generalization. Use a held-out\ndataset if you want generalization feature importances.\n", error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature=" '", weight=0.49537882031697295, std=0.022830631546480108, value=None), FeatureWeight(feature="'", weight=0.48724113035449096, std=0.06073233355473625, value=None), FeatureWeight(feature=" ':'", weight=0.002026786017448323, std=0.00042177254437074206, value=None), FeatureWeight(feature=" 'die'", weight=0.00018728838717436692, std=5.815540116605813e-05, value=None), FeatureWeight(feature=" 'daß'", weight=5.2789993266211256e-05, std=9.617747138705633e-06, value=None), FeatureWeight(feature=" 'des'", weight=3.167541993485123e-05, std=8.583451830753358e-06, value=None), FeatureWeight(feature=" 'auf'", weight=3.092317862383176e-05, std=4.091712354489353e-06, value=None), FeatureWeight(feature=" 'wenn'", weight=1.654042757308627e-05, std=3.419168722620066e-06, value=None), FeatureWeight(feature=" 'eine'", weight=3.2752435833671712e-06, std=4.35019195687948e-07, value=None), FeatureWeight(feature=" 'sind'", weight=3.0778475916592995e-06, std=5.424281438057623e-07, value=None), FeatureWeight(feature=" 'aus'", weight=1.4347384576618439e-06, std=1.2321150009572551e-07, value=None), FeatureWeight(feature=" 'um'", weight=9.817828705127596e-07, std=1.9243427285914506e-07, value=None), FeatureWeight(feature=" 'nur'", weight=7.757097826521786e-07, std=4.859043527931109e-07, value=None), FeatureWeight(feature=" 'diese'", weight=5.718561438383674e-07, std=1.38144554427916e-07, value=None), FeatureWeight(feature=" 'dann'", weight=4.963216778675061e-07, std=3.336380299538805e-08, value=None), FeatureWeight(feature=" 'haben'", weight=4.231732531279064e-07, std=4.8816445436542396e-08, value=None), FeatureWeight(feature=" 'unter'", weight=3.848104884740522e-07, std=1.229216354011724e-07, value=None), FeatureWeight(feature=" 'solches'", weight=2.8688301259016666e-07, std=2.3314886040186334e-08, value=None), FeatureWeight(feature=" 'dieser'", weight=2.5339121390022257e-07, std=7.588244302353669e-08, value=None), FeatureWeight(feature=" 'solche'", weight=1.2503002799757468e-07, std=1.807531054660171e-08, value=None)], remaining=2), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
GERMANC_val_features = eli5.explain_weights_df(perm, feature_names=features_selected)

# %%
test_transform = transformator.transform(GERMANC_test_x)
test_transform = test_transform.toarray()

# %%
perm = PermutationImportance(reg_5['svr']).fit(test_transform, y_pred_test)
eli5.explain_weights(perm, feature_names=features_selected)
# Out:
# Explanation(estimator="PermutationImportance(cv='prefit',\n                      estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,\n                                    epsilon=0.1, gamma='scale', kernel='rbf',\n                                    max_iter=-1, shrinking=True, tol=0.001,\n                                    verbose=False),\n                      n_iter=5, random_state=None, refit=True, scoring=None)", description="\nFeature importances, computed as a decrease in score when feature\nvalues are permuted (i.e. become noise). This is also known as \npermutation importance.\n\nIf feature importances are computed on the same data as used for training, \nthey don't reflect importance of features for generalization. Use a held-out\ndataset if you want generalization feature importances.\n", error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature=" '", weight=0.5345475647968703, std=0.07618104815451779, value=None), FeatureWeight(feature="'", weight=0.5238496010322626, std=0.06442687276806693, value=None), FeatureWeight(feature=" 'die'", weight=0.0003816481904768576, std=7.341660420292763e-05, value=None), FeatureWeight(feature=" ':'", weight=0.00011286796766944996, std=3.3319560726466795e-05, value=None), FeatureWeight(feature=" 'daß'", weight=3.5240231472855045e-05, std=1.1707784336774421e-05, value=None), FeatureWeight(feature=" 'des'", weight=3.499554474928335e-05, std=5.644404511244973e-06, value=None), FeatureWeight(feature=" 'auf'", weight=2.307121182432148e-05, std=4.904430608865971e-06, value=None), FeatureWeight(feature=" 'wenn'", weight=3.2851469038863714e-06, std=7.655149409090697e-07, value=None), FeatureWeight(feature=" 'eine'", weight=2.3454558993440953e-06, std=6.22132454674692e-07, value=None), FeatureWeight(feature=" 'um'", weight=1.350775573083496e-06, std=4.228684930154656e-07, value=None), FeatureWeight(feature=" 'aus'", weight=1.0350362210420626e-06, std=1.3500961886004396e-07, value=None), FeatureWeight(feature=" 'nur'", weight=8.328306888794046e-07, std=1.2223721031684295e-07, value=None), FeatureWeight(feature=" 'sind'", weight=6.447245698426585e-07, std=1.5088624945437645e-07, value=None), FeatureWeight(feature=" 'diese'", weight=5.255110966384535e-07, std=9.267585947781161e-08, value=None), FeatureWeight(feature=" 'dann'", weight=5.0312483519388e-07, std=1.3534244670554962e-07, value=None), FeatureWeight(feature=" 'solche'", weight=3.083694874117526e-07, std=9.604088756752075e-08, value=None), FeatureWeight(feature=" 'solches'", weight=2.86519021663878e-07, std=8.314005312347254e-08, value=None), FeatureWeight(feature=" 'hier'", weight=2.647069925254542e-07, std=6.126485717275646e-08, value=None), FeatureWeight(feature=" 'haben'", weight=1.5808072180156784e-07, std=4.548433891441031e-08, value=None), FeatureWeight(feature=" 'unter'", weight=1.3334398769604404e-07, std=8.433486094414912e-09, value=None)], remaining=2), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
GERMANC_test_features = eli5.explain_weights_df(perm, feature_names=features_selected)

# %%
y_pred_val = reg_5.predict(val_x)
mean_squared_error(val_y, y_pred_val)
# Out:
# 9955.600948926007

# %%
y_pred_test = reg_5.predict(test_x)
mean_squared_error(test_y, y_pred_test)
# Out:
# 8958.889061190974

# %%
y_pred_val = pd.DataFrame(y_pred_val, columns=['Predicted_y'])

diff_pred_true_val = pd.concat([y_pred_val,val_y], axis=1)

diff_pred_true_val['Difference'] = diff_pred_true_val.Predicted_y - diff_pred_true_val.Publication_year


y_pred_test = pd.DataFrame(y_pred_test, columns=['Predicted_y'])

diff_pred_true_test = pd.concat([y_pred_test, test_y], axis=1)

diff_pred_true_test['Difference'] = diff_pred_true_test.Predicted_y - diff_pred_true_test.Publication_year

# %%
diff_pred_true_val.to_csv('/Volumes/Korpora/Exp3_results/GERMANC_DTA_Exp3_Reg5_Labels_val.csv',sep=';')
diff_pred_true_test.to_csv('/Volumes/Korpora/Exp3_results/GERMANC_DTA_Exp3_Reg5_Labels_test.csv',sep=';')

# %%
val_transform = transformator.transform(val_x)
val_transform = val_transform.toarray()

# %%
perm = PermutationImportance(reg_5['svr']).fit(val_transform, y_pred_val)
eli5.explain_weights(perm, feature_names=features_selected)
# Out:
# Explanation(estimator="PermutationImportance(cv='prefit',\n                      estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,\n                                    epsilon=0.1, gamma='scale', kernel='rbf',\n                                    max_iter=-1, shrinking=True, tol=0.001,\n                                    verbose=False),\n                      n_iter=5, random_state=None, refit=True, scoring=None)", description="\nFeature importances, computed as a decrease in score when feature\nvalues are permuted (i.e. become noise). This is also known as \npermutation importance.\n\nIf feature importances are computed on the same data as used for training, \nthey don't reflect importance of features for generalization. Use a held-out\ndataset if you want generalization feature importances.\n", error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature=" 'die'", weight=1.0000994851448775, std=0.00033431560172334776, value=None), FeatureWeight(feature=" '", weight=0.8900442124955644, std=0.12007617597499937, value=None), FeatureWeight(feature="'", weight=0.8801649221630428, std=0.09223828319464297, value=None), FeatureWeight(feature=" 'auf'", weight=0.6090265970727097, std=0.1662952099916753, value=None), FeatureWeight(feature=" 'daß'", weight=0.5958338316507078, std=0.1634982294733342, value=None), FeatureWeight(feature=" 'des'", weight=0.5770662511214985, std=0.13963139767167745, value=None), FeatureWeight(feature=" 'eine'", weight=0.5443871737526254, std=0.19197988302271313, value=None), FeatureWeight(feature=" ':'", weight=0.5129376870532384, std=0.21204411853352842, value=None), FeatureWeight(feature=" 'nur'", weight=0.46206602999138785, std=0.18712095588211036, value=None), FeatureWeight(feature=" 'aus'", weight=0.35380533427754146, std=0.10198962350408472, value=None), FeatureWeight(feature=" 'wenn'", weight=0.2810276851891917, std=0.17653993552608566, value=None), FeatureWeight(feature=" 'haben'", weight=0.27439609888103667, std=0.09763066908070556, value=None), FeatureWeight(feature=" 'um'", weight=0.20503006622111436, std=0.16046945559814907, value=None), FeatureWeight(feature=" 'unter'", weight=0.1963786344466281, std=0.09581614104216361, value=None), FeatureWeight(feature=" 'hier'", weight=0.15930478915184373, std=0.13812316701337987, value=None), FeatureWeight(feature=" 'diese'", weight=0.05121241226080677, std=0.08204689764627718, value=None), FeatureWeight(feature=" 'dann'", weight=0.050068497457550175, std=0.05813950847482539, value=None), FeatureWeight(feature=" 'machen'", weight=0.035271915578964676, std=0.051955200028136694, value=None), FeatureWeight(feature=" 'dieser'", weight=0.019421950119225297, std=0.023594061835779903, value=None), FeatureWeight(feature=" 'solche'", weight=0.0007407579063651859, std=0.0014037762723101475, value=None)], remaining=2), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
GERMANC_DTA_val_features = eli5.explain_weights_df(perm, feature_names=features_selected)

# %%
test_transform = transformator.transform(test_x)
test_transform = test_transform.toarray()

# %%
perm = PermutationImportance(reg_5['svr']).fit(test_transform, y_pred_test)
eli5.explain_weights(perm, feature_names=features_selected)
# Out:
# Explanation(estimator="PermutationImportance(cv='prefit',\n                      estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,\n                                    epsilon=0.1, gamma='scale', kernel='rbf',\n                                    max_iter=-1, shrinking=True, tol=0.001,\n                                    verbose=False),\n                      n_iter=5, random_state=None, refit=True, scoring=None)", description="\nFeature importances, computed as a decrease in score when feature\nvalues are permuted (i.e. become noise). This is also known as \npermutation importance.\n\nIf feature importances are computed on the same data as used for training, \nthey don't reflect importance of features for generalization. Use a held-out\ndataset if you want generalization feature importances.\n", error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature="'", weight=0.9547200254288413, std=0.10651429882471729, value=None), FeatureWeight(feature=" '", weight=0.9382335629577941, std=0.13310543268570546, value=None), FeatureWeight(feature=" 'die'", weight=0.8959503726228384, std=0.07111952154897278, value=None), FeatureWeight(feature=" 'auf'", weight=0.5493826953235982, std=0.1423426580242488, value=None), FeatureWeight(feature=" 'eine'", weight=0.5240169061185916, std=0.05663298223476638, value=None), FeatureWeight(feature=" 'des'", weight=0.5040794097659821, std=0.06526087992051281, value=None), FeatureWeight(feature=" 'daß'", weight=0.48189027268215445, std=0.10810456365465068, value=None), FeatureWeight(feature=" ':'", weight=0.4485421729876789, std=0.10972201102232357, value=None), FeatureWeight(feature=" 'nur'", weight=0.3874104549334826, std=0.10434545144068304, value=None), FeatureWeight(feature=" 'wenn'", weight=0.38004294499952523, std=0.11368184633741414, value=None), FeatureWeight(feature=" 'um'", weight=0.2691031297214025, std=0.12538305935661698, value=None), FeatureWeight(feature=" 'aus'", weight=0.26627763355227035, std=0.15328803371137162, value=None), FeatureWeight(feature=" 'haben'", weight=0.20087149522066014, std=0.10858709018313935, value=None), FeatureWeight(feature=" 'unter'", weight=0.1434906644189362, std=0.09064985091962934, value=None), FeatureWeight(feature=" 'dieser'", weight=0.06166714203432464, std=0.07369718190966021, value=None), FeatureWeight(feature=" 'dann'", weight=0.060316383760031324, std=0.039303484146203556, value=None), FeatureWeight(feature=" 'sind'", weight=0.049100306791321865, std=0.05895227612339593, value=None), FeatureWeight(feature=" 'diese'", weight=0.04062501022281517, std=0.044970500982561605, value=None), FeatureWeight(feature=" 'hier'", weight=0.03144565090715383, std=0.03334749271333441, value=None), FeatureWeight(feature=" 'machen'", weight=0.017506513758735843, std=0.01326207456779751, value=None)], remaining=2), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
GERMANC_DTA_test_features = eli5.explain_weights_df(perm, feature_names=features_selected)

# %%
GERMANC_train_features.to_csv('/Volumes/Korpora/Exp3_results/GERMANC_train_features_Exp3.csv', sep=';')
GERMANC_val_features.to_csv('/Volumes/Korpora/Exp3_results/GERMANC_val_features_Exp3.csv', sep=';')
GERMANC_test_features.to_csv('/Volumes/Korpora/Exp3_results/GERMANC_test_features_Exp3.csv', sep=';')
GERMANC_DTA_val_features.to_csv('/Volumes/Korpora/Exp3_results/GERMANC_over_DTA_val_features_Exp3.csv', sep=';')
GERMANC_DTA_test_features.to_csv('/Volumes/Korpora/Exp3_results/GERMANC_over_DTA_test_features_Exp3.csv', sep=';')

# %%
ARCHER_train_full = pd.read_csv('/Volumes/Korpora/Train/ARCHER_train_tokenized.csv', sep=';')
ARCHER_val_full = pd.read_csv('/Volumes/Korpora/Val/ARCHER_val_tokenized.csv', sep=';')
ARCHER_test_full = pd.read_csv('/Volumes/Korpora/Test/ARCHER_test_tokenized.csv', sep=';')

# %%
ARCHER_train_full = ARCHER_train_full[(ARCHER_train_full.Year.str.len()== 4) & (ARCHER_train_full.Year.str.isnumeric())]

ARCHER_val_full = ARCHER_val_full[(ARCHER_val_full.Year.str.len()== 4) & (ARCHER_val_full.Year.str.isnumeric())]

ARCHER_test_full = ARCHER_test_full[(ARCHER_test_full.Year.str.len()== 4) & (ARCHER_test_full.Year.str.isnumeric())]

# %%
print('Length train set: ',len(ARCHER_train_full))
print('Length validation set: ', len(ARCHER_val_full))
print('Length test set: ', len(ARCHER_test_full))
# Out:
# Length train set:  1049
# Length validation set:  264
# Length test set:  329

# %%
ARCHER_train_x = ARCHER_train_full['Text']
ARCHER_train_y = ARCHER_train_full['Year'].astype(int)

ARCHER_val_x = ARCHER_val_full['Text']
ARCHER_val_y = ARCHER_val_full['Year'].astype(int)

ARCHER_test_x = ARCHER_test_full['Text']
ARCHER_test_y = ARCHER_test_full['Year'].astype(int)

# %%
reg_5 = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 500)),
                    ('feature_selector', SelectKBest(f_regression, k='all')),
                         ('svr', svm.SVR())
                        ])

# %%
reg_5.fit(ARCHER_train_x, ARCHER_train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=500,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x117122560>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k='all',
#                              score_func=<function f_regression at 0x116a48a70>)),
#                 ('svr',
#                  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                      gamma='scale', kernel='rbf', max_iter=-1, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_5.predict(ARCHER_train_x)
mean_squared_error(ARCHER_train_y, y_pred_train)
# Out:
# 8633.760705404035

# %%
y_pred_val = reg_5.predict(ARCHER_val_x)
mean_squared_error(ARCHER_val_y, y_pred_val)
# Out:
# 8939.260952494482

# %%
reg_5 = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 800)),
                    ('feature_selector', SelectKBest(f_regression, k='all')),
                         ('svr', svm.SVR())
                        ])

# %%
reg_5.fit(ARCHER_train_x, ARCHER_train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=800,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x117122560>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k='all',
#                              score_func=<function f_regression at 0x116a48a70>)),
#                 ('svr',
#                  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                      gamma='scale', kernel='rbf', max_iter=-1, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_5.predict(ARCHER_train_x)
mean_squared_error(ARCHER_train_y, y_pred_train)
# Out:
# 8615.109274365492

# %%
y_pred_val = reg_5.predict(ARCHER_val_x)
mean_squared_error(ARCHER_val_y, y_pred_val)
# Out:
# 8959.347967264155

# %%
reg_5 = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 300)),
                    ('feature_selector', SelectKBest(f_regression, k='all')),
                         ('svr', svm.SVR())
                        ])

# %%
reg_5.fit(ARCHER_train_x, ARCHER_train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=300,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x117122560>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k='all',
#                              score_func=<function f_regression at 0x116a48a70>)),
#                 ('svr',
#                  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                      gamma='scale', kernel='rbf', max_iter=-1, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_5.predict(ARCHER_train_x)
mean_squared_error(ARCHER_train_y, y_pred_train)
# Out:
# 8651.164847682081

# %%
y_pred_val = reg_5.predict(ARCHER_val_x)
mean_squared_error(ARCHER_val_y, y_pred_val)
# Out:
# 8948.290702038592

# %%
reg_5 = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 300)),
                    ('feature_selector', SelectKBest(f_regression, k=178)),
                         ('svr', svm.SVR())
                        ])

# %%
reg_5.fit(ARCHER_train_x, ARCHER_train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=300,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x117122560>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k=178,
#                              score_func=<function f_regression at 0x116a48a70>)),
#                 ('svr',
#                  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                      gamma='scale', kernel='rbf', max_iter=-1, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_5.predict(ARCHER_train_x)
mean_squared_error(ARCHER_train_y, y_pred_train)
# Out:
# 8848.914934746368

# %%
y_pred_val = reg_5.predict(ARCHER_val_x)
mean_squared_error(ARCHER_val_y, y_pred_val)
# Out:
# 9333.850424572334

# %%
reg_5 = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 500)),
                    ('feature_selector', SelectKBest(f_regression, k=100)),
                         ('svr', svm.SVR())
                        ])

# %%
reg_5.fit(ARCHER_train_x, ARCHER_train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=500,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x117122560>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k=100,
#                              score_func=<function f_regression at 0x116a48a70>)),
#                 ('svr',
#                  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                      gamma='scale', kernel='rbf', max_iter=-1, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_5.predict(ARCHER_train_x)
mean_squared_error(ARCHER_train_y, y_pred_train)
# Out:
# 8838.223785384655

# %%
y_pred_val = reg_5.predict(ARCHER_val_x)
mean_squared_error(ARCHER_val_y, y_pred_val)
# Out:
# 9316.181223676746

# %%
reg_5 = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 500)),
                    ('feature_selector', SelectKBest(f_regression, k=130)),
                         ('svr', svm.SVR())
                        ])

# %%
reg_5.fit(ARCHER_train_x, ARCHER_train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=500,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x117122560>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k=130,
#                              score_func=<function f_regression at 0x116a48a70>)),
#                 ('svr',
#                  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                      gamma='scale', kernel='rbf', max_iter=-1, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_5.predict(ARCHER_train_x)
mean_squared_error(ARCHER_train_y, y_pred_train)
# Out:
# 8603.066798842648

# %%
y_pred_val = reg_5.predict(ARCHER_val_x)
mean_squared_error(ARCHER_val_y, y_pred_val)
# Out:
# 8916.03416212663

# %%
y_pred_test = reg_5.predict(ARCHER_test_x)
mean_squared_error(ARCHER_test_y, y_pred_test)
# Out:
# 8495.802980948689

# %%
y_pred_train = pd.DataFrame(y_pred_train, columns=['Predicted_y'])

diff_pred_true_train = pd.concat([y_pred_train, ARCHER_train_y], axis=1)

diff_pred_true_train['Difference'] = diff_pred_true_train.Predicted_y - diff_pred_true_train.Year
    

y_pred_val = pd.DataFrame(y_pred_val, columns=['Predicted_y'])

diff_pred_true_val = pd.concat([y_pred_val, ARCHER_val_y], axis=1)

diff_pred_true_val['Difference'] = diff_pred_true_val.Predicted_y - diff_pred_true_val.Year


y_pred_test = pd.DataFrame(y_pred_test, columns=['Predicted_y'])

diff_pred_true_test = pd.concat([y_pred_test, ARCHER_test_y], axis=1)

diff_pred_true_test['Difference'] = diff_pred_true_test.Predicted_y - diff_pred_true_test.Year

# %%
diff_pred_true_train.to_csv('/Volumes/Korpora/Exp3_results/ARCHER_Exp3_Reg5_Labels_train.csv',sep=';')
diff_pred_true_val.to_csv('/Volumes/Korpora/Exp3_results/ARCHER_Exp3_Reg5_Labels_val.csv',sep=';')
diff_pred_true_test.to_csv('/Volumes/Korpora/Exp3_results/ARCHER_Exp3_Reg5_Labels_test.csv',sep=';')

# %%
transformator = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 500)),
                    ('feature_selector', SelectKBest(f_regression, k=130))
                        ])

# %%
train_transform = transformator.fit_transform(ARCHER_train_x, ARCHER_train_y)
train_transform = train_transform.toarray()

# %%
features = transformator['feature_selector'].get_support()
feature_names = transformator['unigram_vectorizer'].get_feature_names()

features_selected = features_to_names(features, feature_names)

# %%
perm = PermutationImportance(reg_5['svr']).fit(train_transform, y_pred_train)
eli5.explain_weights(perm, feature_names=features_selected)
# Out:
# Explanation(estimator="PermutationImportance(cv='prefit',\n                      estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,\n                                    epsilon=0.1, gamma='scale', kernel='rbf',\n                                    max_iter=-1, shrinking=True, tol=0.001,\n                                    verbose=False),\n                      n_iter=5, random_state=None, refit=True, scoring=None)", description="\nFeature importances, computed as a decrease in score when feature\nvalues are permuted (i.e. become noise). This is also known as \npermutation importance.\n\nIf feature importances are computed on the same data as used for training, \nthey don't reflect importance of features for generalization. Use a held-out\ndataset if you want generalization feature importances.\n", error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature=" '.'", weight=0.7293688688137427, std=0.03741649624157552, value=None), FeatureWeight(feature=" 'the'", weight=0.4641747767428825, std=0.009685443184842322, value=None), FeatureWeight(feature=" '", weight=0.14624663311646777, std=0.006234575853198464, value=None), FeatureWeight(feature="'", weight=0.1439934155012476, std=0.004440563838331466, value=None), FeatureWeight(feature=" 'of'", weight=0.021819317970610052, std=0.001815483605648576, value=None), FeatureWeight(feature=" 'and'", weight=0.007513560803855767, std=0.0003629071588542152, value=None), FeatureWeight(feature=" 'a'", weight=0.005092817975926112, std=0.0004022574529822121, value=None), FeatureWeight(feature=" 'in'", weight=0.004845772905008716, std=0.00013567913683761642, value=None), FeatureWeight(feature=" 'to'", weight=0.004670183965856878, std=0.0002066470544945496, value=None), FeatureWeight(feature=' "\'\'"', weight=0.0019522822535519735, std=0.00012207161011665047, value=None), FeatureWeight(feature=" '``'", weight=0.0019047785072060952, std=0.00011930493653813854, value=None), FeatureWeight(feature=" ';'", weight=0.0016374181239840802, std=4.2253549842149774e-05, value=None), FeatureWeight(feature=" ''", weight=0.0014728575148004852, std=8.606959733538856e-05, value=None), FeatureWeight(feature=" '--'", weight=0.0012369998355717504, std=0.00010285936767733537, value=None), FeatureWeight(feature=" ':'", weight=0.0008526003820664485, std=0.00013679260105032122, value=None), FeatureWeight(feature=" 'is'", weight=0.0006151178628632792, std=3.378780556034864e-05, value=None), FeatureWeight(feature=" 'you'", weight=0.0005214108460190436, std=0.00010228685270804881, value=None), FeatureWeight(feature=" 'was'", weight=0.0004955109126369317, std=3.2849677386389734e-05, value=None), FeatureWeight(feature=" 'that'", weight=0.00037313726458114703, std=1.2476414223643777e-05, value=None), FeatureWeight(feature=" 'he'", weight=0.0003647658146139321, std=7.049222138856921e-05, value=None)], remaining=110), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
ARCHER_train_features = eli5.explain_weights_df(perm, feature_names=features_selected)

# %%
val_transform = transformator.transform(ARCHER_val_x)
val_transform = val_transform.toarray()

# %%
perm = PermutationImportance(reg_5['svr']).fit(val_transform, y_pred_val)
eli5.explain_weights(perm, feature_names=features_selected)
# Out:
# Explanation(estimator="PermutationImportance(cv='prefit',\n                      estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,\n                                    epsilon=0.1, gamma='scale', kernel='rbf',\n                                    max_iter=-1, shrinking=True, tol=0.001,\n                                    verbose=False),\n                      n_iter=5, random_state=None, refit=True, scoring=None)", description="\nFeature importances, computed as a decrease in score when feature\nvalues are permuted (i.e. become noise). This is also known as \npermutation importance.\n\nIf feature importances are computed on the same data as used for training, \nthey don't reflect importance of features for generalization. Use a held-out\ndataset if you want generalization feature importances.\n", error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature=" '.'", weight=0.7022400254441314, std=0.024232810669507537, value=None), FeatureWeight(feature=" 'the'", weight=0.45069335545212075, std=0.03745623965125333, value=None), FeatureWeight(feature="'", weight=0.1506446770503998, std=0.0037425005895452006, value=None), FeatureWeight(feature=" '", weight=0.1461611529221511, std=0.008805029946754807, value=None), FeatureWeight(feature=" 'of'", weight=0.019936466574522325, std=0.0019203374279682856, value=None), FeatureWeight(feature=" 'and'", weight=0.008609824198616977, std=0.0010272174815980817, value=None), FeatureWeight(feature=" 'to'", weight=0.0053559315229212865, std=0.0008643115506760298, value=None), FeatureWeight(feature=" 'in'", weight=0.00504222292237364, std=0.0003348969442858449, value=None), FeatureWeight(feature=" 'a'", weight=0.004854242575797007, std=0.0005940826895794553, value=None), FeatureWeight(feature=' "\'\'"', weight=0.002632802340814844, std=0.0008847159191267749, value=None), FeatureWeight(feature=" '``'", weight=0.0025004039745432525, std=0.000553540063126501, value=None), FeatureWeight(feature=" ';'", weight=0.0019968785855460913, std=6.142722118720841e-05, value=None), FeatureWeight(feature=" ':'", weight=0.001852250939402844, std=0.0006834704434843476, value=None), FeatureWeight(feature=" ''", weight=0.001380883899700014, std=0.00010480130246870586, value=None), FeatureWeight(feature=" '--'", weight=0.0010029237576380412, std=0.00014284703813932659, value=None), FeatureWeight(feature=" 'was'", weight=0.0005964031216770139, std=4.623232725685022e-05, value=None), FeatureWeight(feature=" 'is'", weight=0.0005256423728302595, std=5.768084261511336e-05, value=None), FeatureWeight(feature=" 'he'", weight=0.00047170074290476817, std=0.0001353755882290571, value=None), FeatureWeight(feature=" 'that'", weight=0.0004269999214094877, std=8.797889321808372e-05, value=None), FeatureWeight(feature=" 'you'", weight=0.0003642328519943172, std=5.699053492428759e-05, value=None)], remaining=110), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
ARCHER_val_features = eli5.explain_weights_df(perm, feature_names=features_selected)

# %%
test_transform = transformator.transform(ARCHER_test_x)
test_transform = test_transform.toarray()

# %%
perm = PermutationImportance(reg_5['svr']).fit(test_transform, y_pred_test)
eli5.explain_weights(perm, feature_names=features_selected)
# Out:
# Explanation(estimator="PermutationImportance(cv='prefit',\n                      estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,\n                                    epsilon=0.1, gamma='scale', kernel='rbf',\n                                    max_iter=-1, shrinking=True, tol=0.001,\n                                    verbose=False),\n                      n_iter=5, random_state=None, refit=True, scoring=None)", description="\nFeature importances, computed as a decrease in score when feature\nvalues are permuted (i.e. become noise). This is also known as \npermutation importance.\n\nIf feature importances are computed on the same data as used for training, \nthey don't reflect importance of features for generalization. Use a held-out\ndataset if you want generalization feature importances.\n", error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature=" '.'", weight=0.8006955991991959, std=0.029355658409582836, value=None), FeatureWeight(feature=" 'the'", weight=0.4426420442828688, std=0.041596481000909284, value=None), FeatureWeight(feature=" '", weight=0.1654503814197114, std=0.008523355368496298, value=None), FeatureWeight(feature="'", weight=0.16469043834085298, std=0.005093998718745852, value=None), FeatureWeight(feature=" 'of'", weight=0.02135849568363659, std=0.0028049829191513615, value=None), FeatureWeight(feature=" 'and'", weight=0.007864151298794697, std=0.000598004992398964, value=None), FeatureWeight(feature=" ':'", weight=0.006167109387301317, std=0.0013907193943880534, value=None), FeatureWeight(feature=" 'a'", weight=0.005732466562997351, std=0.0005008403946454486, value=None), FeatureWeight(feature=" 'in'", weight=0.004622252353300271, std=0.00035541020562769013, value=None), FeatureWeight(feature=" 'to'", weight=0.004514389923622963, std=0.0003924292037411072, value=None), FeatureWeight(feature=" '``'", weight=0.0022880788487638303, std=0.0007054373229437486, value=None), FeatureWeight(feature=' "\'\'"', weight=0.0019968417106112748, std=0.0007852100249149714, value=None), FeatureWeight(feature=" ''", weight=0.0017744352941399199, std=0.00025586005247645803, value=None), FeatureWeight(feature=" ';'", weight=0.0016236228257660913, std=7.131612988312461e-05, value=None), FeatureWeight(feature=" '--'", weight=0.0009917788291435414, std=0.0004417943546572467, value=None), FeatureWeight(feature=" 'you'", weight=0.0008817117740558711, std=0.0001732519451851642, value=None), FeatureWeight(feature=" 'is'", weight=0.0006860376622405351, std=3.4344716361628717e-05, value=None), FeatureWeight(feature=" 'that'", weight=0.0005006857995859093, std=8.04687494859819e-05, value=None), FeatureWeight(feature=" 'was'", weight=0.0004962002725354298, std=6.582253093806854e-05, value=None), FeatureWeight(feature=' "\'s"', weight=0.0002738777411873228, std=3.148298377345273e-05, value=None)], remaining=110), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
ARCHER_test_features = eli5.explain_weights_df(perm, feature_names=features_selected)

# %%
CLMET_train_full = pd.read_csv('/Volumes/Korpora/Train/CLMET_train_tokenized.csv', sep=';')
CLMET_val_full = pd.read_csv('/Volumes/Korpora/Val/CLMET_val_tokenized.csv', sep=';')
CLMET_test_full = pd.read_csv('/Volumes/Korpora/Test/CLMET_test_tokenized.csv', sep=';')

# %%
#drop rows with invalid data types
CLMET_train_full = CLMET_train_full[CLMET_train_full.Year.str.len()== 4]
CLMET_val_full = CLMET_val_full[CLMET_val_full.Year.str.len()== 4]
CLMET_test_full = CLMET_test_full[CLMET_test_full.Year.str.len()== 4]

# %%
CLMET_train_x = CLMET_train_full['Text']
CLMET_train_y = CLMET_train_full['Year'].astype(int)

CLMET_val_x = CLMET_val_full['Text']
CLMET_val_y = CLMET_val_full['Year'].astype(int)

CLMET_test_x = CLMET_test_full['Text']
CLMET_test_y = CLMET_test_full['Year'].astype(int)

# %%
print('Length train set: ',len(CLMET_train_full))
print('Length validation set: ', len(CLMET_val_full))
print('Length test set: ', len(CLMET_test_full))
# Out:
# Length train set:  186
# Length validation set:  47
# Length test set:  60

# %%
y_pred_val = reg_5.predict(CLMET_val_x)
mean_squared_error(CLMET_val_y, y_pred_val)
# Out:
# 3205.398612412842

# %%
y_pred_test = reg_5.predict(CLMET_test_x)
mean_squared_error(CLMET_test_y, y_pred_test)
# Out:
# 3673.107374950346

# %%
y_pred_val = pd.DataFrame(y_pred_val, columns=['Predicted_y'])

diff_pred_true_val = pd.concat([y_pred_val, CLMET_val_y], axis=1)

diff_pred_true_val['Difference'] = diff_pred_true_val.Predicted_y - diff_pred_true_val.Year


y_pred_test = pd.DataFrame(y_pred_test, columns=['Predicted_y'])

diff_pred_true_test = pd.concat([y_pred_test, CLMET_test_y], axis=1)

diff_pred_true_test['Difference'] = diff_pred_true_test.Predicted_y - diff_pred_true_test.Year

# %%
diff_pred_true_val.to_csv('/Volumes/Korpora/Exp3_results/ARCHER_over_CLMET_Exp3_Reg5_Labels_val.csv',sep=';')
diff_pred_true_test.to_csv('/Volumes/Korpora/Exp3_results/ARCHER_over_CLMET_Exp3_Reg5_Labels_test.csv',sep=';')

# %%
val_transform = transformator.transform(CLMET_val_x)
val_transform = val_transform.toarray()

# %%
perm = PermutationImportance(reg_5['svr']).fit(val_transform, y_pred_val)
eli5.explain_weights(perm, feature_names=features_selected)
# Out:
# Explanation(estimator="PermutationImportance(cv='prefit',\n                      estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,\n                                    epsilon=0.1, gamma='scale', kernel='rbf',\n                                    max_iter=-1, shrinking=True, tol=0.001,\n                                    verbose=False),\n                      n_iter=5, random_state=None, refit=True, scoring=None)", description="\nFeature importances, computed as a decrease in score when feature\nvalues are permuted (i.e. become noise). This is also known as \npermutation importance.\n\nIf feature importances are computed on the same data as used for training, \nthey don't reflect importance of features for generalization. Use a held-out\ndataset if you want generalization feature importances.\n", error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature=" '", weight=1.0472423181406736, std=0.0001363303020987567, value=None), FeatureWeight(feature="'", weight=1.04679677035461, std=0.0007357394262495268, value=None), FeatureWeight(feature=" '.'", weight=0.9319691074507986, std=0.20343171718421257, value=None), FeatureWeight(feature=" 'of'", weight=0.8549947808161271, std=0.23480188848739122, value=None), FeatureWeight(feature=" 'and'", weight=0.8281889698829369, std=0.3468844338627603, value=None), FeatureWeight(feature=" 'a'", weight=0.8236396600436707, std=0.2742978206604948, value=None), FeatureWeight(feature=" 'to'", weight=0.744046264342043, std=0.3871084902999512, value=None), FeatureWeight(feature=" 'in'", weight=0.6247830417194378, std=0.3786927314397616, value=None), FeatureWeight(feature=" 'that'", weight=0.6244064806455742, std=0.3780182996882343, value=None), FeatureWeight(feature=" '``'", weight=0.6102946767788978, std=0.17424522242786994, value=None), FeatureWeight(feature=" 'it'", weight=0.5581135551144578, std=0.23864191688432906, value=None), FeatureWeight(feature=" 'the'", weight=0.553424155911378, std=0.3082254845919334, value=None), FeatureWeight(feature=" 'was'", weight=0.5299318640683819, std=0.013013604091285977, value=None), FeatureWeight(feature=" ';'", weight=0.52291981867105, std=0.3278856070280223, value=None), FeatureWeight(feature=" 'his'", weight=0.4916746622398195, std=0.4455218493659757, value=None), FeatureWeight(feature=" 'for'", weight=0.4772984873582815, std=0.2524167034683473, value=None), FeatureWeight(feature=" 'is'", weight=0.45622487126350375, std=0.08159875241607144, value=None), FeatureWeight(feature=" 'not'", weight=0.4477563439259786, std=0.19990081477913707, value=None), FeatureWeight(feature=" '?'", weight=0.41899058028668057, std=0.3886318830632152, value=None), FeatureWeight(feature=" 'at'", weight=0.4171318940908848, std=0.34527137763424137, value=None)], remaining=110), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
ARCHER_CLMET_val_features = eli5.explain_weights_df(perm, feature_names=features_selected)

# %%
test_transform = transformator.transform(CLMET_test_x)
test_transform = test_transform.toarray()

# %%
perm = PermutationImportance(reg_5['svr']).fit(test_transform, y_pred_test)
eli5.explain_weights(perm, feature_names=features_selected)
# Out:
# Explanation(estimator="PermutationImportance(cv='prefit',\n                      estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,\n                                    epsilon=0.1, gamma='scale', kernel='rbf',\n                                    max_iter=-1, shrinking=True, tol=0.001,\n                                    verbose=False),\n                      n_iter=5, random_state=None, refit=True, scoring=None)", description="\nFeature importances, computed as a decrease in score when feature\nvalues are permuted (i.e. become noise). This is also known as \npermutation importance.\n\nIf feature importances are computed on the same data as used for training, \nthey don't reflect importance of features for generalization. Use a held-out\ndataset if you want generalization feature importances.\n", error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature="'", weight=1.1855729615509112, std=0.3382387357307563, value=None), FeatureWeight(feature=" '", weight=1.0176278527372635, std=0.0021212352323377384, value=None), FeatureWeight(feature=" 'that'", weight=1.0159172567416883, std=0.0009702331147393305, value=None), FeatureWeight(feature=" '.'", weight=0.9509396059634732, std=0.13090485974160954, value=None), FeatureWeight(feature=" ';'", weight=0.8873933248591014, std=0.4324380227558813, value=None), FeatureWeight(feature=" 'he'", weight=0.8587700721946506, std=0.23575466998834024, value=None), FeatureWeight(feature=" 'with'", weight=0.8568843064646992, std=0.2608903521737588, value=None), FeatureWeight(feature=" 'of'", weight=0.8460719844476825, std=0.3406948308813252, value=None), FeatureWeight(feature=" 'the'", weight=0.8454396069082609, std=0.2985712809732891, value=None), FeatureWeight(feature=" 'in'", weight=0.8118095875502332, std=0.4058077907285434, value=None), FeatureWeight(feature=" 'my'", weight=0.8096056145061343, std=0.5961862309945957, value=None), FeatureWeight(feature=" 'to'", weight=0.7911006940302754, std=0.2908875565815508, value=None), FeatureWeight(feature=" 'have'", weight=0.7594483836191172, std=0.38727458587420444, value=None), FeatureWeight(feature=" 'but'", weight=0.6531160357767595, std=0.4167019239743559, value=None), FeatureWeight(feature=" 'it'", weight=0.6157943371037734, std=0.48776253633497607, value=None), FeatureWeight(feature=" 'at'", weight=0.6097902071355895, std=0.497713796657759, value=None), FeatureWeight(feature=" 'no'", weight=0.6043676080298209, std=0.31808047072987095, value=None), FeatureWeight(feature=" 'one'", weight=0.5966340783936837, std=0.4855139206272137, value=None), FeatureWeight(feature=" 'been'", weight=0.5964622972923074, std=0.22109414250283077, value=None), FeatureWeight(feature=" 'not'", weight=0.5854762933814346, std=0.38358439237115266, value=None)], remaining=110), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
ARCHER_CLMET_test_features = eli5.explain_weights_df(perm, feature_names=features_selected)

# %%
ARCHER_train_features.to_csv('/Volumes/Korpora/Exp3_results/ARCHER_train_features_Exp3.csv', sep=';')
ARCHER_val_features.to_csv('/Volumes/Korpora/Exp3_results/ARCHER_val_features_Exp3.csv', sep=';')
ARCHER_test_features.to_csv('/Volumes/Korpora/Exp3_results/ARCHER_test_features_Exp3.csv', sep=';')
ARCHER_CLMET_val_features.to_csv('/Volumes/Korpora/Exp3_results/ARCHER_over_CLMET_val_features_Exp3.csv', sep=';')
ARCHER_CLMET_test_features.to_csv('/Volumes/Korpora/Exp3_results/ARCHER_over_CLMET_test_features_Exp3.csv', sep=';')

# %%
reg_5 = Pipeline([('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 176)),
                    ('feature_selector', SelectKBest(f_regression, k=32)),
                         ('svr', svm.SVR())]
                  )

# %%
reg_5.fit(CLMET_train_x, CLMET_train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=176,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x117122560>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k=32,
#                              score_func=<function f_regression at 0x116a48a70>)),
#                 ('svr',
#                  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                      gamma='scale', kernel='rbf', max_iter=-1, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_5.predict(CLMET_train_x)
mean_squared_error(CLMET_train_y, y_pred_train)
# Out:
# 3135.455358670207

# %%
y_pred_val = reg_5.predict(CLMET_val_x)
mean_squared_error(CLMET_val_y, y_pred_val)
# Out:
# 3176.0535454246083

# %%
reg_5 = Pipeline([('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 176)),
                    ('feature_selector', SelectKBest(f_regression, k=44)),
                         ('svr', svm.SVR())]
                  )

# %%
reg_5.fit(CLMET_train_x, CLMET_train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=176,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x117122560>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k=44,
#                              score_func=<function f_regression at 0x116a48a70>)),
#                 ('svr',
#                  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                      gamma='scale', kernel='rbf', max_iter=-1, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_5.predict(CLMET_train_x)
mean_squared_error(CLMET_train_y, y_pred_train)
# Out:
# 3252.3095711052456

# %%
y_pred_val = reg_5.predict(CLMET_val_x)
mean_squared_error(CLMET_val_y, y_pred_val)
# Out:
# 3266.5405354176924

# %%
reg_5 = Pipeline([('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 176)),
                    ('feature_selector', SelectKBest(f_regression, k=10)),
                         ('svr', svm.SVR())]
                  )

# %%
reg_5.fit(CLMET_train_x, CLMET_train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=176,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x117122560>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k=10,
#                              score_func=<function f_regression at 0x116a48a70>)),
#                 ('svr',
#                  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                      gamma='scale', kernel='rbf', max_iter=-1, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_5.predict(CLMET_train_x)
mean_squared_error(CLMET_train_y, y_pred_train)
# Out:
# 3156.3395364013472

# %%
y_pred_val = reg_5.predict(CLMET_val_x)
mean_squared_error(CLMET_val_y, y_pred_val)
# Out:
# 3204.033880101949

# %%
reg_5 = Pipeline([('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 176)),
                    ('feature_selector', SelectKBest(f_regression, k=32)),
                         ('svr', svm.SVR())]
                  )

# %%
reg_5.fit(CLMET_train_x, CLMET_train_y)
# Out:
# Pipeline(memory=None,
#          steps=[('unigram_vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=176,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenizer_word at 0x117122560>,
#                                  vocabulary=None)),
#                 ('feature_selector',
#                  SelectKBest(k=32,
#                              score_func=<function f_regression at 0x116a48a70>)),
#                 ('svr',
#                  SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#                      gamma='scale', kernel='rbf', max_iter=-1, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)

# %%
y_pred_train = reg_5.predict(CLMET_train_x)
mean_squared_error(CLMET_train_y, y_pred_train)
# Out:
# 3135.455358670207

# %%
y_pred_val = reg_5.predict(CLMET_val_x)
mean_squared_error(CLMET_val_y, y_pred_val)
# Out:
# 3176.0535454246083

# %%
y_pred_test = reg_5.predict(CLMET_test_x)
mean_squared_error(CLMET_test_y, y_pred_test)
# Out:
# 3404.0427042578312

# %%
y_pred_train = pd.DataFrame(y_pred_train, columns=['Predicted_y'])

diff_pred_true_train = pd.concat([y_pred_train, CLMET_train_y], axis=1)

diff_pred_true_train['Difference'] = diff_pred_true_train.Predicted_y - diff_pred_true_train.Year
    

y_pred_val = pd.DataFrame(y_pred_val, columns=['Predicted_y'])

diff_pred_true_val = pd.concat([y_pred_val, CLMET_val_y], axis=1)

diff_pred_true_val['Difference'] = diff_pred_true_val.Predicted_y - diff_pred_true_val.Year


y_pred_test = pd.DataFrame(y_pred_test, columns=['Predicted_y'])

diff_pred_true_test = pd.concat([y_pred_test, CLMET_test_y], axis=1)

diff_pred_true_test['Difference'] = diff_pred_true_test.Predicted_y - diff_pred_true_test.Year

# %%
diff_pred_true_train.to_csv('/Volumes/Korpora/Exp3_results/CLMET_Exp3_Reg5_Labels_train.csv',sep=';')
diff_pred_true_val.to_csv('/Volumes/Korpora/Exp3_results/CLMET_Exp3_Reg5_Labels_val.csv',sep=';')
diff_pred_true_test.to_csv('/Volumes/Korpora/Exp3_results/CLMET_Exp3_Reg5_Labels_test.csv',sep=';')

# %%
transformator = Pipeline([ ('unigram_vectorizer', CountVectorizer(tokenizer=tokenizer_word, min_df = 176)),
                    ('feature_selector', SelectKBest(f_regression, k=32))
                        ])

# %%
train_transform = transformator.fit_transform(CLMET_train_x, CLMET_train_y)
train_transform = train_transform.toarray()

# %%
features = transformator['feature_selector'].get_support()
feature_names = transformator['unigram_vectorizer'].get_feature_names()

features_selected = features_to_names(features, feature_names)

# %%
perm = PermutationImportance(reg_5['svr']).fit(train_transform, y_pred_train)
eli5.explain_weights(perm, feature_names=features_selected)
# Out:
# Explanation(estimator="PermutationImportance(cv='prefit',\n                      estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,\n                                    epsilon=0.1, gamma='scale', kernel='rbf',\n                                    max_iter=-1, shrinking=True, tol=0.001,\n                                    verbose=False),\n                      n_iter=5, random_state=None, refit=True, scoring=None)", description="\nFeature importances, computed as a decrease in score when feature\nvalues are permuted (i.e. become noise). This is also known as \npermutation importance.\n\nIf feature importances are computed on the same data as used for training, \nthey don't reflect importance of features for generalization. Use a held-out\ndataset if you want generalization feature importances.\n", error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature=" 'my'", weight=0.9714483782170535, std=0.09851143539018828, value=None), FeatureWeight(feature=" '-'", weight=0.7055413739301185, std=0.02836593203257793, value=None), FeatureWeight(feature=" 'there'", weight=0.0719144224909932, std=0.010265852981037778, value=None), FeatureWeight(feature=" '?'", weight=0.057885827165295244, std=0.006045426881790152, value=None), FeatureWeight(feature=" 'your'", weight=0.042653445164905365, std=0.008770183313795196, value=None), FeatureWeight(feature=" 'up'", weight=0.015910154144329967, std=0.0012461014175214815, value=None), FeatureWeight(feature=" 'every'", weight=0.008473779001333814, std=0.002515914178948791, value=None), FeatureWeight(feature=" 'down'", weight=0.003013069394104573, std=0.0005777584628429366, value=None), FeatureWeight(feature=" 'like'", weight=0.0028945462783876775, std=0.0006428560415973344, value=None), FeatureWeight(feature=" 'shall'", weight=0.0019087430325863907, std=0.0004438101942321543, value=None), FeatureWeight(feature=" 'come'", weight=0.0015199864200775126, std=0.00026590291196860273, value=None), FeatureWeight(feature=" 'back'", weight=0.0008995736051626846, std=0.00010442401703874527, value=None), FeatureWeight(feature=" 'till'", weight=0.00035080922606076646, std=0.00016643353279791097, value=None), FeatureWeight(feature=" 'work'", weight=0.00029876648747844125, std=0.00011997006796067121, value=None), FeatureWeight(feature=" 'face'", weight=0.00026607330963563937, std=4.552781047401317e-05, value=None), FeatureWeight(feature=" 'just'", weight=0.0002538727425215548, std=4.2247317332537476e-05, value=None), FeatureWeight(feature=" 'get'", weight=0.00022776849048216085, std=1.229416083170081e-05, value=None), FeatureWeight(feature=" 'things'", weight=0.0001529641103381385, std=3.676694087437304e-05, value=None), FeatureWeight(feature=" 'round'", weight=0.00010297278454163283, std=5.539257466702242e-05, value=None), FeatureWeight(feature=" 'reason'", weight=0.00010162204887060877, std=4.5302661887019146e-05, value=None)], remaining=12), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
CLMET_train_features = eli5.explain_weights_df(perm, feature_names=features_selected)

# %%
val_transform = transformator.transform(CLMET_val_x)
val_transform = val_transform.toarray()

# %%
perm = PermutationImportance(reg_5['svr']).fit(val_transform, y_pred_val)
eli5.explain_weights(perm, feature_names=features_selected)
# Out:
# Explanation(estimator="PermutationImportance(cv='prefit',\n                      estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,\n                                    epsilon=0.1, gamma='scale', kernel='rbf',\n                                    max_iter=-1, shrinking=True, tol=0.001,\n                                    verbose=False),\n                      n_iter=5, random_state=None, refit=True, scoring=None)", description="\nFeature importances, computed as a decrease in score when feature\nvalues are permuted (i.e. become noise). This is also known as \npermutation importance.\n\nIf feature importances are computed on the same data as used for training, \nthey don't reflect importance of features for generalization. Use a held-out\ndataset if you want generalization feature importances.\n", error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature=" '-'", weight=0.9880316203351194, std=0.18665664186186737, value=None), FeatureWeight(feature=" 'my'", weight=0.9866187807406022, std=0.13326851606627912, value=None), FeatureWeight(feature=" 'there'", weight=0.12603476257843146, std=0.007708109313300333, value=None), FeatureWeight(feature=" '?'", weight=0.09567706267923656, std=0.012683997445411158, value=None), FeatureWeight(feature=" 'your'", weight=0.05944351619295392, std=0.011760420940289187, value=None), FeatureWeight(feature=" 'up'", weight=0.03129212432577204, std=0.004143153742733268, value=None), FeatureWeight(feature=" 'like'", weight=0.00677038677086228, std=0.00043421148122776515, value=None), FeatureWeight(feature=" 'every'", weight=0.004753059649451985, std=0.0007046599109172844, value=None), FeatureWeight(feature=" 'shall'", weight=0.004231309851361798, std=0.0009944993318395702, value=None), FeatureWeight(feature=" 'down'", weight=0.003635772954525951, std=0.000650531826518961, value=None), FeatureWeight(feature=" 'come'", weight=0.001788973343030964, std=0.0002123032711319281, value=None), FeatureWeight(feature=" 'back'", weight=0.0009697527240744464, std=8.772266498912376e-05, value=None), FeatureWeight(feature=" 'get'", weight=0.00047471992548997477, std=7.452083710354975e-05, value=None), FeatureWeight(feature=" 'just'", weight=0.00027831530587947296, std=5.7057523612856306e-05, value=None), FeatureWeight(feature=" 'face'", weight=0.00020981409187954548, std=4.176433905042915e-05, value=None), FeatureWeight(feature=" 'person'", weight=0.0001586125309922526, std=0.00010420925375643528, value=None), FeatureWeight(feature=" 'things'", weight=0.00015729816672644948, std=6.79573085089087e-05, value=None), FeatureWeight(feature=" 'till'", weight=0.00014511156582557304, std=2.542323839099593e-05, value=None), FeatureWeight(feature=" 'round'", weight=0.00014080642568241596, std=2.9288055742194106e-05, value=None), FeatureWeight(feature=" 'work'", weight=0.0001356250213957688, std=2.3119423049513894e-05, value=None)], remaining=12), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
CLMET_val_features = eli5.explain_weights_df(perm, feature_names=features_selected)

# %%
test_transform = transformator.transform(CLMET_test_x)
test_transform = test_transform.toarray()

# %%
perm = PermutationImportance(reg_5['svr']).fit(test_transform, y_pred_test)
eli5.explain_weights(perm, feature_names=features_selected)
# Out:
# Explanation(estimator="PermutationImportance(cv='prefit',\n                      estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,\n                                    epsilon=0.1, gamma='scale', kernel='rbf',\n                                    max_iter=-1, shrinking=True, tol=0.001,\n                                    verbose=False),\n                      n_iter=5, random_state=None, refit=True, scoring=None)", description="\nFeature importances, computed as a decrease in score when feature\nvalues are permuted (i.e. become noise). This is also known as \npermutation importance.\n\nIf feature importances are computed on the same data as used for training, \nthey don't reflect importance of features for generalization. Use a held-out\ndataset if you want generalization feature importances.\n", error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature=" 'my'", weight=0.8920888645365286, std=0.19819300367205878, value=None), FeatureWeight(feature=" '-'", weight=0.7500265202854364, std=0.092799960660907, value=None), FeatureWeight(feature=" 'there'", weight=0.10367102629556732, std=0.02240012222739543, value=None), FeatureWeight(feature=" '?'", weight=0.10244321692310347, std=0.0068180736571330355, value=None), FeatureWeight(feature=" 'your'", weight=0.06086874032868426, std=0.03248312582256122, value=None), FeatureWeight(feature=" 'up'", weight=0.023578524623035002, std=0.012397197660715622, value=None), FeatureWeight(feature=" 'every'", weight=0.02180489566116728, std=0.016542227959119544, value=None), FeatureWeight(feature=" 'shall'", weight=0.01680949056103087, std=0.02120700768343918, value=None), FeatureWeight(feature=" 'like'", weight=0.0046282115307201945, std=0.0008657376615850199, value=None), FeatureWeight(feature=" 'down'", weight=0.00335544094150273, std=0.0014558957427930996, value=None), FeatureWeight(feature=" 'hope'", weight=0.0025857984086433026, std=0.004150564100674245, value=None), FeatureWeight(feature=" 'come'", weight=0.0015180098208410265, std=0.0005538050624470189, value=None), FeatureWeight(feature=" 'person'", weight=0.0013551801522244, std=0.0008440476262114469, value=None), FeatureWeight(feature=" 'till'", weight=0.0009746153978966276, std=0.000854533551524402, value=None), FeatureWeight(feature=" 'reason'", weight=0.0007206548580589, std=0.00022988722674580615, value=None), FeatureWeight(feature=" 'back'", weight=0.0006629387989389723, std=0.00019906310564950526, value=None), FeatureWeight(feature=" 'things'", weight=0.000648740146807003, std=7.218873231843673e-05, value=None), FeatureWeight(feature=" 'happy'", weight=0.0005033248233622167, std=0.00046381816530424437, value=None), FeatureWeight(feature=" 'just'", weight=0.0003385416673081787, std=0.00012163151251653526, value=None), FeatureWeight(feature=" 'get'", weight=0.00026317851331796315, std=0.00011073007050261581, value=None)], remaining=12), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
CLMET_test_features = eli5.explain_weights_df(perm, feature_names=features_selected)

# %%
y_pred_val = reg_5.predict(ARCHER_val_x)
mean_squared_error(ARCHER_val_y, y_pred_val)
# Out:
# 10109.930975614836

# %%
y_pred_test = reg_5.predict(ARCHER_test_x)
mean_squared_error(ARCHER_test_y, y_pred_test)
# Out:
# 9719.350960203037

# %%
y_pred_val = pd.DataFrame(y_pred_val, columns=['Predicted_y'])

diff_pred_true_val = pd.concat([y_pred_val, ARCHER_val_y], axis=1)

diff_pred_true_val['Difference'] = diff_pred_true_val.Predicted_y - diff_pred_true_val.Year


y_pred_test = pd.DataFrame(y_pred_test, columns=['Predicted_y'])

diff_pred_true_test = pd.concat([y_pred_test, ARCHER_test_y], axis=1)

diff_pred_true_test['Difference'] = diff_pred_true_test.Predicted_y - diff_pred_true_test.Year

# %%
diff_pred_true_val.to_csv('/Volumes/Korpora/Exp3_results/CLMET_over_ARCHER_Exp3_Reg5_Labels_val.csv',sep=';')
diff_pred_true_test.to_csv('/Volumes/Korpora/Exp3_results/CLMET_over_ARCHER_Exp3_Reg5_Labels_test.csv',sep=';')

# %%
val_transform = transformator.transform(ARCHER_val_x)
val_transform = val_transform.toarray()

# %%
perm = PermutationImportance(reg_5['svr']).fit(val_transform, y_pred_val)
eli5.explain_weights(perm, feature_names=features_selected)
# Out:
# Explanation(estimator="PermutationImportance(cv='prefit',\n                      estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,\n                                    epsilon=0.1, gamma='scale', kernel='rbf',\n                                    max_iter=-1, shrinking=True, tol=0.001,\n                                    verbose=False),\n                      n_iter=5, random_state=None, refit=True, scoring=None)", description="\nFeature importances, computed as a decrease in score when feature\nvalues are permuted (i.e. become noise). This is also known as \npermutation importance.\n\nIf feature importances are computed on the same data as used for training, \nthey don't reflect importance of features for generalization. Use a held-out\ndataset if you want generalization feature importances.\n", error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature=" 'my'", weight=1.3382744308667371, std=0.0758547711133528, value=None), FeatureWeight(feature=" '-'", weight=0.3189139410131184, std=0.004853169970371034, value=None), FeatureWeight(feature=" '?'", weight=0.2682922952433993, std=0.018907287067252927, value=None), FeatureWeight(feature=" 'there'", weight=0.12364309925316423, std=0.007410185018705402, value=None), FeatureWeight(feature=" 'your'", weight=0.04527062202819856, std=0.00395297451099739, value=None), FeatureWeight(feature=" 'up'", weight=0.02594117905289852, std=0.0017213279822182082, value=None), FeatureWeight(feature=" 'like'", weight=0.0074481530249788765, std=0.0004207542574129638, value=None), FeatureWeight(feature=" 'down'", weight=0.005754412656318331, std=0.00026369766287560523, value=None), FeatureWeight(feature=" 'every'", weight=0.003192850144245263, std=0.00011968717418636223, value=None), FeatureWeight(feature=" 'back'", weight=0.0030712019900298593, std=0.00022267496340342335, value=None), FeatureWeight(feature=" 'shall'", weight=0.002606553219803609, std=0.00020316932718236172, value=None), FeatureWeight(feature=" 'come'", weight=0.001682888178033859, std=8.05718202263585e-05, value=None), FeatureWeight(feature=" 'get'", weight=0.0016580659079044936, std=0.0002257772534342661, value=None), FeatureWeight(feature=" 'work'", weight=0.0009892926931762912, std=1.2541407587861793e-05, value=None), FeatureWeight(feature=" 'just'", weight=0.0007801861742675386, std=2.038966496237999e-05, value=None), FeatureWeight(feature=" 'going'", weight=0.0005008056916583125, std=4.294961693549271e-05, value=None), FeatureWeight(feature=" 'right'", weight=0.00034779626916205955, std=2.5584828258734812e-05, value=None), FeatureWeight(feature=" 'something'", weight=0.0002438163417625372, std=4.961704012844522e-06, value=None), FeatureWeight(feature=" 'face'", weight=0.0002106272585415736, std=5.508079577204409e-06, value=None), FeatureWeight(feature=" 'round'", weight=0.000150630497785742, std=4.35303318036879e-06, value=None)], remaining=12), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
CLMET_ARCHER_val_features = eli5.explain_weights_df(perm, feature_names=features_selected)

# %%
test_transform = transformator.transform(ARCHER_test_x)
test_transform = test_transform.toarray()

# %%
perm = PermutationImportance(reg_5['svr']).fit(test_transform, y_pred_test)
eli5.explain_weights(perm, feature_names=features_selected)
# Out:
# Explanation(estimator="PermutationImportance(cv='prefit',\n                      estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,\n                                    epsilon=0.1, gamma='scale', kernel='rbf',\n                                    max_iter=-1, shrinking=True, tol=0.001,\n                                    verbose=False),\n                      n_iter=5, random_state=None, refit=True, scoring=None)", description="\nFeature importances, computed as a decrease in score when feature\nvalues are permuted (i.e. become noise). This is also known as \npermutation importance.\n\nIf feature importances are computed on the same data as used for training, \nthey don't reflect importance of features for generalization. Use a held-out\ndataset if you want generalization feature importances.\n", error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature=" 'my'", weight=1.5420115368124447, std=0.0318103013489446, value=None), FeatureWeight(feature=" '?'", weight=0.5167833974965236, std=0.05008255268717212, value=None), FeatureWeight(feature=" '-'", weight=0.33686294634191555, std=0.00850018200412925, value=None), FeatureWeight(feature=" 'there'", weight=0.09852923130731477, std=0.005189412533117384, value=None), FeatureWeight(feature=" 'your'", weight=0.08686126267715186, std=0.0032575416019981493, value=None), FeatureWeight(feature=" 'up'", weight=0.022606385015504805, std=0.0006899188341997516, value=None), FeatureWeight(feature=" 'like'", weight=0.005858217827266321, std=0.00012405572162654056, value=None), FeatureWeight(feature=" 'every'", weight=0.005158037044058661, std=0.0002870359038177688, value=None), FeatureWeight(feature=" 'down'", weight=0.004933118357489952, std=0.00021540655659552452, value=None), FeatureWeight(feature=" 'shall'", weight=0.0038546754734763546, std=0.00012182228990713575, value=None), FeatureWeight(feature=" 'come'", weight=0.002859598813002728, std=6.62070813593254e-05, value=None), FeatureWeight(feature=" 'back'", weight=0.0012585534146553501, std=4.043077448272152e-05, value=None), FeatureWeight(feature=" 'get'", weight=0.0011446478723038168, std=2.580460012940379e-05, value=None), FeatureWeight(feature=" 'just'", weight=0.000731001281487087, std=1.1665248764607335e-05, value=None), FeatureWeight(feature=" 'right'", weight=0.0007080902178687509, std=2.9779624439805287e-05, value=None), FeatureWeight(feature=" 'work'", weight=0.0006421968140180034, std=1.465009676580884e-05, value=None), FeatureWeight(feature=" 'going'", weight=0.00023168579715246996, std=5.287683217662493e-06, value=None), FeatureWeight(feature=" 'face'", weight=0.00021050865687863852, std=8.587014023545143e-06, value=None), FeatureWeight(feature=" 'reason'", weight=0.0001990269069816586, std=5.110366060242633e-06, value=None), FeatureWeight(feature=" 'till'", weight=0.00015094932125832018, std=8.326703682532475e-06, value=None)], remaining=12), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %%
CLMET_ARCHER_test_features = eli5.explain_weights_df(perm, feature_names=features_selected)

# %%
CLMET_train_features.to_csv('/Volumes/Korpora/Exp3_results/CLMET_train_features_Exp3.csv', sep=';')
CLMET_val_features.to_csv('/Volumes/Korpora/Exp3_results/CLMET_val_features_Exp3.csv', sep=';')
CLMET_test_features.to_csv('/Volumes/Korpora/Exp3_results/CLMET_test_features_Exp3.csv', sep=';')
CLMET_ARCHER_val_features.to_csv('/Volumes/Korpora/Exp3_results/CLMET_over_ARCHER_val_features_Exp3.csv', sep=';')
CLMET_ARCHER_test_features.to_csv('/Volumes/Korpora/Exp3_results/CLMET_over_ARCHER_test_features_Exp3.csv', sep=';')
